# %%
from __future__ import absolute_import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import sklearn
from datetime import datetime

# %%
trn_df = pd.read_csv('./train/train.csv', encoding='utf8')
tst_df = pd.read_csv('./test/test.csv', encoding='utf8')
trn_df.head()
# Out:
#    acqic   bacno    cano    conam  contp  csmcu ecfg  etymd flbmk flg_3dsmk  \
# 0   6881  113261   38038   513.80      5      0    N      0     N         N
# 1      0  134508   45725   465.62      5      0    N      2     N         N
# 2   6881   15408  188328   513.80      5      0    N      0     N         N
# 3   6716  157159   29967  1016.11      5     62    N      5     N         N
# 4   5975  105985   81305   713.66      5     62    N      4     N         N
#
#    ...  iterm  locdt     loctm  mcc  mchno  ovrlt  scity  stocn stscd    txkey
# 0  ...      0     33  172652.0  457  59333      N      0    102     0   516056
# 1  ...      0      9  105114.0  451      0      N   5817    102     0     4376
# 2  ...      0      6  152458.0  457  59333      N      0    102     0   483434
# 3  ...      0      5  172946.0  247  50436      N   3281    102     0  1407164
# 4  ...      0      6  182129.0  263  93775      N   5817    102     0  1051004
#
# [5 rows x 23 columns]

# %%
trn_df['loctm'] = trn_df.loctm.astype(int).astype(str).str.zfill(6)
trn_df['loctm'] = pd.to_datetime(trn_df.loctm, format='%H%M%S', errors='raise')
trn_df['loctm'] = trn_df.loctm.dt.time

tst_df['loctm'] = tst_df.loctm.astype(int).astype(str).str.zfill(6)
tst_df['loctm'] = pd.to_datetime(tst_df.loctm, format='%H%M%S', errors='raise')
tst_df['loctm'] = tst_df.loctm.dt.time

# %%
feature_list = ['locdt', 'loctm', 'contp', 'etymd', 'mcc', 'conam', 'ecfg', 'insfg', 'iterm', 'stocn', 'stscd', 'hcefg', 'csmcu']
trn_df = trn_df[feature_list + ['fraud_ind']]
trn_df = trn_df.dropna()
tst_df = tst_df[feature_list]
trn_df.head()
# Out:
#    locdt     loctm  contp  etymd  mcc    conam ecfg insfg  iterm  stocn  \
# 0     33  172652.0      5      0  457   513.80    N     N      0    102
# 1      9  105114.0      5      2  451   465.62    N     N      0    102
# 2      6  152458.0      5      0  457   513.80    N     N      0    102
# 3      5  172946.0      5      5  247  1016.11    N     N      0    102
# 4      6  182129.0      5      4  263   713.66    N     N      0    102
#
#    stscd  hcefg  csmcu  fraud_ind
# 0      0      5      0          0
# 1      0      0      0          0
# 2      0      5      0          0
# 3      0      5     62          0
# 4      0      5     62          0

# %%
def add_noise(series, noise_level):
    return series * (1 + noise_level * np.random.randn(len(series)))

def target_encode(trn_series=None, 
                  tst_series=None, 
                  target=None, 
                  min_samples_leaf=1, 
                  smoothing=1,
                  noise_level=0):
    """
    Smoothing is computed like in the following paper by Daniele Micci-Barreca
    https://kaggle2.blob.core.windows.net/forum-message-attachments/225952/7441/high%20cardinality%20categoricals.pdf
    trn_series : training categorical feature as a pd.Series
    tst_series : test categorical feature as a pd.Series
    target : target data as a pd.Series
    min_samples_leaf (int) : minimum samples to take category average into account
    smoothing (int) : smoothing effect to balance categorical average vs prior  
    """ 
    assert len(trn_series) == len(target)
    assert trn_series.name == tst_series.name
    temp = pd.concat([trn_series, target], axis=1)
    # Compute target mean 
    averages = temp.groupby(by=trn_series.name)[target.name].agg(["mean", "count"])
    # Compute smoothing
    smoothing = 1 / (1 + np.exp(-(averages["count"] - min_samples_leaf) / smoothing))
    # Apply average function to all target data
    prior = target.mean()
    # The bigger the count the less full_avg is taken into account
    averages[target.name] = prior * (1 - smoothing) + averages["mean"] * smoothing
    averages.drop(["mean", "count"], axis=1, inplace=True)
    # Apply averages to trn and tst series
    ft_trn_series = pd.merge(
        trn_series.to_frame(trn_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=trn_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_trn_series.index = trn_series.index 
    ft_tst_series = pd.merge(
        tst_series.to_frame(tst_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=tst_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_tst_series.index = tst_series.index
    return add_noise(ft_trn_series, noise_level), add_noise(ft_tst_series, noise_level)

# %%
trn_contp, tst_contp = target_encode(trn_df["contp"], 
                         tst_df["contp"], 
                         target=trn_df.fraud_ind, 
                         min_samples_leaf=100,
                         smoothing=10,
                         noise_level=0.01)

# %%
trn_etymd, tst_etymd = target_encode(trn_df["etymd"], 
                         tst_df["etymd"], 
                         target=trn_df.fraud_ind, 
                         min_samples_leaf=100,
                         smoothing=10,
                         noise_level=0.01)

# %%
trn_iterm, tst_iterm = target_encode(trn_df["iterm"], 
                         tst_df["iterm"], 
                         target=trn_df.fraud_ind, 
                         min_samples_leaf=100,
                         smoothing=10,
                         noise_level=0.01)

# %%
trn_stocn, tst_stocn = target_encode(trn_df["stocn"], 
                         tst_df["stocn"], 
                         target=trn_df.fraud_ind, 
                         min_samples_leaf=100,
                         smoothing=10,
                         noise_level=0.01)

# %%
trn_hcefg, tst_hcefg = target_encode(trn_df["hcefg"], 
                         tst_df["hcefg"], 
                         target=trn_df.fraud_ind, 
                         min_samples_leaf=100,
                         smoothing=10,
                         noise_level=0.01)

# %%
trn_csmcu, tst_csmcu = target_encode(trn_df["csmcu"], 
                         tst_df["csmcu"], 
                         target=trn_df.fraud_ind, 
                         min_samples_leaf=100,
                         smoothing=10,
                         noise_level=0.01)

# %%
trn_ecfg_insfg, tst_ecfg_insfg = pd.get_dummies(trn_df[['ecfg', 'insfg']]), pd.get_dummies(tst_df[['ecfg', 'insfg']])
# trn_insfg, tst_insfg = pd.get_dummies(trn_df['insfg']), pd.get_dummies(tst_df['insfg'])

# %%
target_encode_feature_list = ['contp', 'etymd', 'iterm', 'stocn', 'hcefg', 'csmcu']
one_hot_encode_feature_list = ['ecfg', 'insfg']

# %%
trn_ready = pd.concat([trn_ecfg_insfg, trn_contp, trn_etymd, trn_iterm, trn_stocn, trn_hcefg, trn_csmcu], axis=1)
trn_label = trn_df[['fraud_ind']]
trn_label = pd.get_dummies(trn_label.astype(object))

# %%
tst_ready = pd.concat([tst_ecfg_insfg, tst_contp, tst_etymd, tst_iterm, tst_stocn, tst_hcefg, tst_csmcu], axis=1)
# tst_label = tst_df[['fraud_ind']]

# %%
trn_ready.head()
# Out:
#    ecfg_N  ecfg_Y  insfg_N  insfg_Y  contp_mean  etymd_mean  iterm_mean  \
# 0       1       0        1        0    0.014307    0.001408    0.013701
# 1       1       0        1        0    0.014351    0.020658    0.013587
# 2       1       0        1        0    0.014218    0.001397    0.013712
# 3       1       0        1        0    0.014160    0.000502    0.013584
# 4       1       0        1        0    0.014239    0.000556    0.013794
#
#    stocn_mean  hcefg_mean  csmcu_mean
# 0    0.000945    0.014345    0.001059
# 1    0.000955    0.000387    0.001097
# 2    0.000959    0.014116    0.001089
# 3    0.000948    0.014382    0.007218
# 4    0.000947    0.014028    0.007179

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os
import sys
import tensorflow as tf

# %% [markdown]
# # Method 2

# %%
trn_ready = trn_df[target_encode_feature_list+one_hot_encode_feature_list]

# %%
contp = tf.feature_column.categorical_column_with_vocabulary_list('contp', [5, 3, 6, 2, 4, 0, 1])
etymd = tf.feature_column.categorical_column_with_vocabulary_list('etymd', [0, 2, 5, 4, 8, 1, 9, 6, 3, 7, 10])
iterm = tf.feature_column.categorical_column_with_vocabulary_list('iterm', [0, 1, 2, 8, 3, 4, 7, 6, 5])
stocn = tf.feature_column.categorical_column_with_vocabulary_list('stocn', list(trn_df.stocn.unique()))
hcefg = tf.feature_column.categorical_column_with_vocabulary_list('hcefg', [5, 0, 3, 1, 2, 7, 8, 9, 6])
csmcu = tf.feature_column.categorical_column_with_vocabulary_list('csmcu', list(trn_df.csmcu.unique()))
# Binary
ecfg = tf.feature_column.categorical_column_with_vocabulary_list('ecfg', ['N', 'Y'])
insfg =tf.feature_column.categorical_column_with_vocabulary_list('insfg', ['N', 'Y'])


contp_one_hot = tf.feature_column.indicator_column(contp)
etymd_one_hot = tf.feature_column.indicator_column(etymd)
iterm_one_hot = tf.feature_column.indicator_column(iterm)
stocn_one_hot = tf.feature_column.indicator_column(stocn)
hcefg_one_hot = tf.feature_column.indicator_column(hcefg)
csmcu_one_hot = tf.feature_column.indicator_column(csmcu)
ecfg_one_hot = tf.feature_column.indicator_column(ecfg)
insfg_one_hot = tf.feature_column.indicator_column(insfg)
feature_cols = [contp_one_hot, etymd_one_hot, iterm_one_hot, stocn_one_hot, hcefg_one_hot, csmcu_one_hot, ecfg_one_hot, insfg_one_hot]

# %% [markdown]
# # Method 1

# %%
# Multi
contp_mean = tf.feature_column.numeric_column('contp_mean')
etymd_mean = tf.feature_column.numeric_column('etymd_mean')
iterm_mean = tf.feature_column.numeric_column('iterm_mean')
stocn_mean = tf.feature_column.numeric_column('stocn_mean')
hcefg_mean = tf.feature_column.numeric_column('hcefg_mean')
csmcu_mean = tf.feature_column.numeric_column('csmcu_mean')
# Binary
ecfg_N = tf.feature_column.numeric_column('ecfg_N')
ecfg_Y = tf.feature_column.numeric_column('ecfg_Y')
insfg_N = tf.feature_column.numeric_column('insfg_N')
insfg_Y = tf.feature_column.numeric_column('insfg_Y')

# %%
trn_label = trn_df[['fraud_ind']]
# labels = tf.feature_column.categorical_column_with_hash_bucket('fraud_ind', hash_bucket_size=2)

# %%
feature_cols = [contp_mean, etymd_mean, iterm_mean, stocn_mean, hcefg_mean, csmcu_mean, ecfg_N, ecfg_Y, insfg_N, insfg_Y]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(trn_df, trn_label, test_size=0.3)

# %%
def input_fn(features, labels=None, training=True, batch_size=256):
    
    """An input function for training or evaluating"""
    # 将输入转换为数据集。
    if labels is not None:
        labels = labels.values.reshape(-1,)
        inputs = (dict(features), labels)
    else:
        inputs = (dict(features))
    dataset = tf.data.Dataset.from_tensor_slices(inputs)
    # 如果在训练模式下混淆并重复数据。
    if training:
        dataset = dataset.shuffle(1000).repeat()
    dataset = dataset.batch(batch_size)
    return dataset

# %%
input_fn(x_train, labels = y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\data\util\structure.py in normalize_element(element)
#      90       try:
# ---> 91         spec = type_spec_from_value(t, use_fallback=False)
#      92       except TypeError:
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\data\util\structure.py in type_spec_from_value(element, use_fallback)
#     456   raise TypeError("Could not build a TypeSpec for %r with type %s" %
# --> 457                   (element, type(element).__name__))
#
# TypeError: Could not build a TypeSpec for 757105      821.57
# 72551       513.80
# 73500      1280.93
# 614503      714.64
# 1133650     611.19
#             ...
# 106858       74.77
# 810703      899.73
# 45553      1105.33
# 848269      488.75
# 692289      513.80
# Name: conam, Length: 1065250, dtype: float64 with type Series
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-82-40617cdc3bb1> in <module>
# ----> 1 input_fn(x_train, labels = y_train)
#
# <ipython-input-81-77d4dc644cd1> in input_fn(features, labels, training, batch_size)
#       8     else:
#       9         inputs = (dict(features))
# ---> 10     dataset = tf.data.Dataset.from_tensor_slices(inputs)
#      11     # 如果在训练模式下混淆并重复数据。
#      12     if training:
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in from_tensor_slices(tensors)
#     433       Dataset: A `Dataset`.
#     434     """
# --> 435     return TensorSliceDataset(tensors)
#     436
#     437   class _GeneratorState(object):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in __init__(self, element)
#    2352   def __init__(self, element):
#    2353     """See `Dataset.from_tensor_slices()` for details."""
# -> 2354     element = structure.normalize_element(element)
#    2355     batched_spec = structure.type_spec_from_value(element)
#    2356     self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\data\util\structure.py in normalize_element(element)
#      94         # the value. As a fallback try converting the value to a tensor.
#      95         normalized_components.append(
# ---> 96             ops.convert_to_tensor(t, name="component_%d" % i))
#      97       else:
#      98         if isinstance(spec, sparse_tensor.SparseTensorSpec):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in convert_to_tensor(value, dtype, name, preferred_dtype, dtype_hint)
#    1182   preferred_dtype = deprecation.deprecated_argument_lookup(
#    1183       "dtype_hint", dtype_hint, "preferred_dtype", preferred_dtype)
# -> 1184   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1185
#    1186
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1240       name=name,
#    1241       preferred_dtype=dtype_hint,
# -> 1242       as_ref=False)
#    1243
#    1244
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_composite_tensors)
#    1294
#    1295     if ret is None:
# -> 1296       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1297
#    1298     if ret is NotImplemented:
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     284                                          as_ref=False):
#     285   _ = as_ref
# --> 286   return constant(v, dtype=dtype, name=name)
#     287
#     288
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     225   """
#     226   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 227                         allow_broadcast=True)
#     228
#     229
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     269       attrs={"value": tensor_value,
#     270              "dtype": dtype_value},
# --> 271       name=name).outputs[0]
#     272   return const_tensor
#     273
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\util\deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3358         raise TypeError("Input #%d is not a tensor: %s" % (idx, a))
#    3359     return self._create_op_internal(op_type, inputs, dtypes, input_types, name,
# -> 3360                                     attrs, op_def, compute_device)
#    3361
#    3362   def _create_op_internal(
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3402       An `Operation` object.
#    3403     """
# -> 3404     self._check_not_finalized()
#    3405     if name is None:
#    3406       name = op_type
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in _check_not_finalized(self)
#    2999     """
#    3000     if self._finalized:
# -> 3001       raise RuntimeError("Graph is finalized and cannot be modified.")
#    3002
#    3003   def _add_op(self, op):
#
# RuntimeError: Graph is finalized and cannot be modified.

# %%
def eval_input_func(features, labels, training=True, batch_size=256):
    labels = labels.values.reshape(-1,)
    """An input function for training or evaluating"""
    # 将输入转换为数据集。
    if labels is not None:
        inputs = (dict(features), labels)
    else:
        inputs = (dict(features))
    dataset = tf.data.Dataset.from_tensor_slices(inputs)

    # 如果在训练模式下混淆并重复数据。
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %%
eval_input_func(x_test, y_test)
# Out:
# <BatchDataset shapes: ({ecfg_N: (None,), ecfg_Y: (None,), insfg_N: (None,), insfg_Y: (None,), contp_mean: (None,), etymd_mean: (None,), iterm_mean: (None,), stocn_mean: (None,), hcefg_mean: (None,), csmcu_mean: (None,)}, (None,)), types: ({ecfg_N: tf.int32, ecfg_Y: tf.int32, insfg_N: tf.int32, insfg_Y: tf.int32, contp_mean: tf.float64, etymd_mean: tf.float64, iterm_mean: tf.float64, stocn_mean: tf.float64, hcefg_mean: tf.float64, csmcu_mean: tf.float64}, tf.int64)>

# %%
model = tf.estimator.LinearClassifier(
    feature_columns=feature_cols,
    n_classes=2
)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\tim19\AppData\Local\Temp\tmp9aer9ixv
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\tim19\\AppData\\Local\\Temp\\tmp9aer9ixv', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000277F70AF710>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
results = model.train(input_fn=lambda: input_fn(x_train, y_train), steps=100000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\tim19\AppData\Local\Temp\tmp9aer9ixv\model.ckpt-5000
# WARNING:tensorflow:From C:\Users\tim19\Anaconda3\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5000 into C:\Users\tim19\AppData\Local\Temp\tmp9aer9ixv\model.ckpt.
# INFO:tensorflow:loss = 0.08527371, step = 5000
# INFO:tensorflow:global_step/sec: 35.3894
# INFO:tensorflow:loss = 0.03924777, step = 5100 (2.810 sec)
# INFO:tensorflow:global_step/sec: 142.153
# INFO:tensorflow:loss = 0.035917934, step = 5200 (0.694 sec)
# INFO:tensorflow:global_step/sec: 151.02
# INFO:tensorflow:loss = 0.030170362, step = 5300 (0.664 sec)
# INFO:tensorflow:global_step/sec: 148.246
# INFO:tensorflow:loss = 0.033637308, step = 5400 (0.675 sec)
# INFO:tensorflow:global_step/sec: 147.554
# INFO:tensorflow:loss = 0.02854881, step = 5500 (0.676 sec)
# INFO:tensorflow:global_step/sec: 145.035
# INFO:tensorflow:loss = 0.02673725, step = 5600 (0.688 sec)
# INFO:tensorflow:global_step/sec: 150.339
# INFO:tensorflow:loss = 0.019400552, step = 5700 (0.665 sec)
# INFO:tensorflow:global_step/sec: 152.521
# INFO:tensorflow:loss = 0.019059442, step = 5800 (0.658 sec)
# INFO:tensorflow:global_step/sec: 156.599
# INFO:tensorflow:loss = 0.032110322, step = 5900 (0.638 sec)
# INFO:tensorflow:global_step/sec: 149.878
# INFO:tensorflow:loss = 0.026792783, step = 6000 (0.667 sec)
# INFO:tensorflow:global_step/sec: 121.729
# INFO:tensorflow:loss = 0.0678384, step = 6100 (0.822 sec)
# INFO:tensorflow:global_step/sec: 127.794
# INFO:tensorflow:loss = 0.051331624, step = 6200 (0.782 sec)
# INFO:tensorflow:global_step/sec: 149.475
# INFO:tensorflow:loss = 0.031466212, step = 6300 (0.670 sec)
# INFO:tensorflow:global_step/sec: 147.331
# INFO:tensorflow:loss = 0.0575163, step = 6400 (0.678 sec)
# INFO:tensorflow:global_step/sec: 154.995
# INFO:tensorflow:loss = 0.0671888, step = 6500 (0.647 sec)
# INFO:tensorflow:global_step/sec: 148.212
# INFO:tensorflow:loss = 0.05425388, step = 6600 (0.674 sec)
# INFO:tensorflow:global_step/sec: 152.846
# INFO:tensorflow:loss = 0.044575658, step = 6700 (0.660 sec)
# INFO:tensorflow:global_step/sec: 154.857
# INFO:tensorflow:loss = 0.028311174, step = 6800 (0.640 sec)
# INFO:tensorflow:global_step/sec: 154.97
# INFO:tensorflow:loss = 0.019407207, step = 6900 (0.644 sec)
# INFO:tensorflow:global_step/sec: 150.126
# INFO:tensorflow:loss = 0.050118215, step = 7000 (0.668 sec)
# INFO:tensorflow:global_step/sec: 148.884
# INFO:tensorflow:loss = 0.03285334, step = 7100 (0.670 sec)
# INFO:tensorflow:global_step/sec: 146.066
# INFO:tensorflow:loss = 0.024431536, step = 7200 (0.686 sec)
# INFO:tensorflow:global_step/sec: 147.944
# INFO:tensorflow:loss = 0.07260053, step = 7300 (0.675 sec)
# INFO:tensorflow:global_step/sec: 152.605
# INFO:tensorflow:loss = 0.041130897, step = 7400 (0.655 sec)
# INFO:tensorflow:global_step/sec: 155.154
# INFO:tensorflow:loss = 0.055665016, step = 7500 (0.645 sec)
# INFO:tensorflow:global_step/sec: 155.12
# INFO:tensorflow:loss = 0.025080012, step = 7600 (0.647 sec)
# INFO:tensorflow:global_step/sec: 137.973
# INFO:tensorflow:loss = 0.057804063, step = 7700 (0.722 sec)
# INFO:tensorflow:global_step/sec: 139.722
# INFO:tensorflow:loss = 0.04268039, step = 7800 (0.717 sec)
# INFO:tensorflow:global_step/sec: 149.303
# INFO:tensorflow:loss = 0.046641342, step = 7900 (0.668 sec)
# INFO:tensorflow:global_step/sec: 145.856
# INFO:tensorflow:loss = 0.029074097, step = 8000 (0.689 sec)
# INFO:tensorflow:global_step/sec: 149.836
# INFO:tensorflow:loss = 0.06590751, step = 8100 (0.670 sec)
# INFO:tensorflow:global_step/sec: 146.957
# INFO:tensorflow:loss = 0.022505151, step = 8200 (0.676 sec)
# INFO:tensorflow:global_step/sec: 154.846
# INFO:tensorflow:loss = 0.06504458, step = 8300 (0.646 sec)
# INFO:tensorflow:global_step/sec: 149.26
# INFO:tensorflow:loss = 0.04806984, step = 8400 (0.669 sec)
# INFO:tensorflow:global_step/sec: 147.428
# INFO:tensorflow:loss = 0.086414926, step = 8500 (0.678 sec)
# INFO:tensorflow:global_step/sec: 152.592
# INFO:tensorflow:loss = 0.03314905, step = 8600 (0.657 sec)
# INFO:tensorflow:global_step/sec: 140.316
# INFO:tensorflow:loss = 0.030869057, step = 8700 (0.712 sec)
# INFO:tensorflow:global_step/sec: 138.683
# INFO:tensorflow:loss = 0.021364585, step = 8800 (0.719 sec)
# INFO:tensorflow:global_step/sec: 150.327
# INFO:tensorflow:loss = 0.036156572, step = 8900 (0.667 sec)
# INFO:tensorflow:global_step/sec: 152.269
# INFO:tensorflow:loss = 0.029793318, step = 9000 (0.658 sec)
# INFO:tensorflow:global_step/sec: 147.858
# INFO:tensorflow:loss = 0.06777481, step = 9100 (0.674 sec)
# INFO:tensorflow:global_step/sec: 138.918
# INFO:tensorflow:loss = 0.016574722, step = 9200 (0.723 sec)
# INFO:tensorflow:global_step/sec: 153.487
# INFO:tensorflow:loss = 0.019831518, step = 9300 (0.650 sec)
# INFO:tensorflow:global_step/sec: 144.933
# INFO:tensorflow:loss = 0.041661065, step = 9400 (0.688 sec)
# INFO:tensorflow:global_step/sec: 152.874
# INFO:tensorflow:loss = 0.05158382, step = 9500 (0.656 sec)
# INFO:tensorflow:global_step/sec: 153.8
# INFO:tensorflow:loss = 0.02370976, step = 9600 (0.649 sec)
# INFO:tensorflow:global_step/sec: 153.958
# INFO:tensorflow:loss = 0.028757934, step = 9700 (0.654 sec)
# INFO:tensorflow:global_step/sec: 143.074
# INFO:tensorflow:loss = 0.036463603, step = 9800 (0.695 sec)
# INFO:tensorflow:global_step/sec: 152.832
# INFO:tensorflow:loss = 0.035597924, step = 9900 (0.657 sec)
# INFO:tensorflow:global_step/sec: 151.605
# INFO:tensorflow:loss = 0.015914526, step = 10000 (0.657 sec)
# INFO:tensorflow:global_step/sec: 150.358
# INFO:tensorflow:loss = 0.048992928, step = 10100 (0.666 sec)
# INFO:tensorflow:global_step/sec: 148.685
# INFO:tensorflow:loss = 0.054684438, step = 10200 (0.676 sec)
# INFO:tensorflow:global_step/sec: 148.286
# INFO:tensorflow:loss = 0.06382057, step = 10300 (0.670 sec)
# INFO:tensorflow:global_step/sec: 146.775
# INFO:tensorflow:loss = 0.08173628, step = 10400 (0.719 sec)
# INFO:tensorflow:global_step/sec: 141.402
# INFO:tensorflow:loss = 0.120029695, step = 10500 (0.669 sec)
# INFO:tensorflow:global_step/sec: 151.25
# INFO:tensorflow:loss = 0.02979165, step = 10600 (0.661 sec)
# INFO:tensorflow:global_step/sec: 150.088
# INFO:tensorflow:loss = 0.05752419, step = 10700 (0.666 sec)
# INFO:tensorflow:global_step/sec: 150.616
# INFO:tensorflow:loss = 0.030257361, step = 10800 (0.664 sec)
# INFO:tensorflow:global_step/sec: 142.698
# INFO:tensorflow:loss = 0.021651866, step = 10900 (0.702 sec)
# INFO:tensorflow:global_step/sec: 138.196
# INFO:tensorflow:loss = 0.068799436, step = 11000 (0.723 sec)
# INFO:tensorflow:global_step/sec: 155.103
# INFO:tensorflow:loss = 0.040419936, step = 11100 (0.645 sec)
# INFO:tensorflow:global_step/sec: 153.206
# INFO:tensorflow:loss = 0.026874553, step = 11200 (0.653 sec)
# INFO:tensorflow:global_step/sec: 152.945
# INFO:tensorflow:loss = 0.044207502, step = 11300 (0.655 sec)
# INFO:tensorflow:global_step/sec: 151.466
# INFO:tensorflow:loss = 0.029910175, step = 11400 (0.660 sec)
# INFO:tensorflow:global_step/sec: 143.932
# INFO:tensorflow:loss = 0.051465426, step = 11500 (0.695 sec)
# INFO:tensorflow:global_step/sec: 148.316
# INFO:tensorflow:loss = 0.05190396, step = 11600 (0.673 sec)
# INFO:tensorflow:global_step/sec: 152.719
# INFO:tensorflow:loss = 0.057298318, step = 11700 (0.660 sec)
# INFO:tensorflow:global_step/sec: 147.819
# INFO:tensorflow:loss = 0.021421881, step = 11800 (0.671 sec)
# INFO:tensorflow:global_step/sec: 145.951
# INFO:tensorflow:loss = 0.02626608, step = 11900 (0.685 sec)
# INFO:tensorflow:global_step/sec: 149.576
# INFO:tensorflow:loss = 0.051274903, step = 12000 (0.669 sec)
# INFO:tensorflow:global_step/sec: 148.963
# INFO:tensorflow:loss = 0.03708569, step = 12100 (0.674 sec)
# INFO:tensorflow:global_step/sec: 143.833
# INFO:tensorflow:loss = 0.030286003, step = 12200 (0.692 sec)
# INFO:tensorflow:global_step/sec: 151.833
# INFO:tensorflow:loss = 0.042065226, step = 12300 (0.660 sec)
# INFO:tensorflow:global_step/sec: 136.839
# INFO:tensorflow:loss = 0.031389542, step = 12400 (0.732 sec)
# INFO:tensorflow:global_step/sec: 152.607
# INFO:tensorflow:loss = 0.04458547, step = 12500 (0.654 sec)
# INFO:tensorflow:global_step/sec: 149.724
# INFO:tensorflow:loss = 0.037659943, step = 12600 (0.667 sec)
# INFO:tensorflow:global_step/sec: 153.991
# INFO:tensorflow:loss = 0.01896734, step = 12700 (0.649 sec)
# INFO:tensorflow:global_step/sec: 145.734
# INFO:tensorflow:loss = 0.048620455, step = 12800 (0.686 sec)
# INFO:tensorflow:global_step/sec: 152.321
# INFO:tensorflow:loss = 0.036236472, step = 12900 (0.658 sec)
# INFO:tensorflow:global_step/sec: 147.333
# INFO:tensorflow:loss = 0.023558281, step = 13000 (0.682 sec)
# INFO:tensorflow:global_step/sec: 148.4
# INFO:tensorflow:loss = 0.035981417, step = 13100 (0.670 sec)
# INFO:tensorflow:global_step/sec: 145.511
# INFO:tensorflow:loss = 0.03367729, step = 13200 (0.687 sec)
# INFO:tensorflow:global_step/sec: 153.881
# INFO:tensorflow:loss = 0.020502396, step = 13300 (0.649 sec)
# INFO:tensorflow:global_step/sec: 141.016
# INFO:tensorflow:loss = 0.050907135, step = 13400 (0.711 sec)
# INFO:tensorflow:global_step/sec: 151.97
# INFO:tensorflow:loss = 0.032955673, step = 13500 (0.657 sec)
# INFO:tensorflow:global_step/sec: 146.132
# INFO:tensorflow:loss = 0.043736305, step = 13600 (0.684 sec)
# INFO:tensorflow:global_step/sec: 147.104
# INFO:tensorflow:loss = 0.03189084, step = 13700 (0.680 sec)
# INFO:tensorflow:global_step/sec: 149.776
# INFO:tensorflow:loss = 0.07961254, step = 13800 (0.667 sec)
# INFO:tensorflow:global_step/sec: 149.048
# INFO:tensorflow:loss = 0.01989492, step = 13900 (0.672 sec)
# INFO:tensorflow:global_step/sec: 152.411
# INFO:tensorflow:loss = 0.024094805, step = 14000 (0.655 sec)
# INFO:tensorflow:global_step/sec: 149.111
# INFO:tensorflow:loss = 0.040319066, step = 14100 (0.671 sec)
# INFO:tensorflow:global_step/sec: 154.189
# INFO:tensorflow:loss = 0.051570855, step = 14200 (0.650 sec)
# INFO:tensorflow:global_step/sec: 150.128
# INFO:tensorflow:loss = 0.025354, step = 14300 (0.665 sec)
# INFO:tensorflow:global_step/sec: 151.587
# INFO:tensorflow:loss = 0.027026683, step = 14400 (0.665 sec)
# INFO:tensorflow:global_step/sec: 150.88
# INFO:tensorflow:loss = 0.031616256, step = 14500 (0.658 sec)
# INFO:tensorflow:global_step/sec: 151.555
# INFO:tensorflow:loss = 0.07637483, step = 14600 (0.660 sec)
# INFO:tensorflow:global_step/sec: 150.018
# INFO:tensorflow:loss = 0.021514274, step = 14700 (0.667 sec)
# INFO:tensorflow:global_step/sec: 152.829
# INFO:tensorflow:loss = 0.023889415, step = 14800 (0.655 sec)
# INFO:tensorflow:global_step/sec: 147.372
# INFO:tensorflow:loss = 0.024311878, step = 14900 (0.678 sec)
# INFO:tensorflow:global_step/sec: 153.263
# INFO:tensorflow:loss = 0.07558389, step = 15000 (0.652 sec)
# INFO:tensorflow:global_step/sec: 150.062
# INFO:tensorflow:loss = 0.035196155, step = 15100 (0.666 sec)
# INFO:tensorflow:global_step/sec: 149.579
# INFO:tensorflow:loss = 0.024940787, step = 15200 (0.669 sec)
# INFO:tensorflow:global_step/sec: 145.934
# INFO:tensorflow:loss = 0.037084337, step = 15300 (0.687 sec)
# INFO:tensorflow:global_step/sec: 152.893
# INFO:tensorflow:loss = 0.07836543, step = 15400 (0.654 sec)
# INFO:tensorflow:global_step/sec: 152.12
# INFO:tensorflow:loss = 0.051125128, step = 15500 (0.656 sec)
# INFO:tensorflow:global_step/sec: 157.134
# INFO:tensorflow:loss = 0.05524127, step = 15600 (0.636 sec)
# INFO:tensorflow:global_step/sec: 150.619
# INFO:tensorflow:loss = 0.050110392, step = 15700 (0.664 sec)
# INFO:tensorflow:global_step/sec: 156.55
# INFO:tensorflow:loss = 0.04764778, step = 15800 (0.642 sec)
# INFO:tensorflow:global_step/sec: 147.168
# INFO:tensorflow:loss = 0.056376807, step = 15900 (0.676 sec)
# INFO:tensorflow:global_step/sec: 149.203
# INFO:tensorflow:loss = 0.04789155, step = 16000 (0.676 sec)
# INFO:tensorflow:global_step/sec: 147.878
# INFO:tensorflow:loss = 0.06651165, step = 16100 (0.670 sec)
# INFO:tensorflow:global_step/sec: 149.953
# INFO:tensorflow:loss = 0.06113275, step = 16200 (0.667 sec)
# INFO:tensorflow:global_step/sec: 156.707
# INFO:tensorflow:loss = 0.037285097, step = 16300 (0.639 sec)
# INFO:tensorflow:global_step/sec: 154.403
# INFO:tensorflow:loss = 0.030644588, step = 16400 (0.647 sec)
# INFO:tensorflow:global_step/sec: 154.546
# INFO:tensorflow:loss = 0.046269596, step = 16500 (0.647 sec)
# INFO:tensorflow:global_step/sec: 152.572
# INFO:tensorflow:loss = 0.05031737, step = 16600 (0.660 sec)
# INFO:tensorflow:global_step/sec: 145.263
# INFO:tensorflow:loss = 0.01693719, step = 16700 (0.684 sec)
# INFO:tensorflow:global_step/sec: 150.1
# INFO:tensorflow:loss = 0.038225025, step = 16800 (0.665 sec)
# INFO:tensorflow:global_step/sec: 149.163
# INFO:tensorflow:loss = 0.026302196, step = 16900 (0.671 sec)
# INFO:tensorflow:global_step/sec: 142.315
# INFO:tensorflow:loss = 0.043943495, step = 17000 (0.702 sec)
# INFO:tensorflow:global_step/sec: 153.773
# INFO:tensorflow:loss = 0.06748256, step = 17100 (0.650 sec)
# INFO:tensorflow:global_step/sec: 147.935
# INFO:tensorflow:loss = 0.05351431, step = 17200 (0.676 sec)
# INFO:tensorflow:global_step/sec: 151.551
# INFO:tensorflow:loss = 0.03992432, step = 17300 (0.660 sec)
# INFO:tensorflow:global_step/sec: 158.65
# INFO:tensorflow:loss = 0.058313303, step = 17400 (0.630 sec)
# INFO:tensorflow:global_step/sec: 156.89
# INFO:tensorflow:loss = 0.03486925, step = 17500 (0.638 sec)
# INFO:tensorflow:global_step/sec: 145.671
# INFO:tensorflow:loss = 0.07889113, step = 17600 (0.686 sec)
# INFO:tensorflow:global_step/sec: 149.289
# INFO:tensorflow:loss = 0.022023443, step = 17700 (0.670 sec)
# INFO:tensorflow:global_step/sec: 144.475
# INFO:tensorflow:loss = 0.07939141, step = 17800 (0.698 sec)
# INFO:tensorflow:global_step/sec: 138.054
# INFO:tensorflow:loss = 0.058302984, step = 17900 (0.718 sec)
# INFO:tensorflow:global_step/sec: 141.855
# INFO:tensorflow:loss = 0.01926618, step = 18000 (0.704 sec)
# INFO:tensorflow:global_step/sec: 122.48
# INFO:tensorflow:loss = 0.025919363, step = 18100 (0.817 sec)
# INFO:tensorflow:global_step/sec: 133.442
# INFO:tensorflow:loss = 0.036056798, step = 18200 (0.749 sec)
# INFO:tensorflow:global_step/sec: 132.927
# INFO:tensorflow:loss = 0.021182153, step = 18300 (0.755 sec)
# INFO:tensorflow:global_step/sec: 129.045
# INFO:tensorflow:loss = 0.013660017, step = 18400 (0.772 sec)
# INFO:tensorflow:global_step/sec: 148.353
# INFO:tensorflow:loss = 0.08018011, step = 18500 (0.674 sec)
# INFO:tensorflow:global_step/sec: 135.712
# INFO:tensorflow:loss = 0.03075393, step = 18600 (0.739 sec)
# INFO:tensorflow:global_step/sec: 135.829
# INFO:tensorflow:loss = 0.025452148, step = 18700 (0.733 sec)
# INFO:tensorflow:global_step/sec: 139.99
# INFO:tensorflow:loss = 0.014018362, step = 18800 (0.716 sec)
# INFO:tensorflow:global_step/sec: 141.414
# INFO:tensorflow:loss = 0.039754193, step = 18900 (0.705 sec)
# INFO:tensorflow:global_step/sec: 145.819
# INFO:tensorflow:loss = 0.039204467, step = 19000 (0.687 sec)
# INFO:tensorflow:global_step/sec: 150.841
# INFO:tensorflow:loss = 0.058040787, step = 19100 (0.663 sec)
# INFO:tensorflow:global_step/sec: 146.949
# INFO:tensorflow:loss = 0.040418677, step = 19200 (0.679 sec)
# INFO:tensorflow:global_step/sec: 150.184
# INFO:tensorflow:loss = 0.021567654, step = 19300 (0.667 sec)
# INFO:tensorflow:global_step/sec: 150.282
# INFO:tensorflow:loss = 0.045180544, step = 19400 (0.665 sec)
# INFO:tensorflow:global_step/sec: 153.624
# INFO:tensorflow:loss = 0.0331005, step = 19500 (0.650 sec)
# INFO:tensorflow:global_step/sec: 141.653
# INFO:tensorflow:loss = 0.05766931, step = 19600 (0.706 sec)
# INFO:tensorflow:global_step/sec: 148.458
# INFO:tensorflow:loss = 0.05523453, step = 19700 (0.677 sec)
# INFO:tensorflow:global_step/sec: 151.051
# INFO:tensorflow:loss = 0.017254736, step = 19800 (0.664 sec)
# INFO:tensorflow:global_step/sec: 140.176
# INFO:tensorflow:loss = 0.04698251, step = 19900 (0.709 sec)
# INFO:tensorflow:global_step/sec: 144.059
# INFO:tensorflow:loss = 0.031663448, step = 20000 (0.693 sec)
# INFO:tensorflow:global_step/sec: 152.767
# INFO:tensorflow:loss = 0.026229126, step = 20100 (0.656 sec)
# INFO:tensorflow:global_step/sec: 143.127
# INFO:tensorflow:loss = 0.05574196, step = 20200 (0.699 sec)
# INFO:tensorflow:global_step/sec: 153.122
# INFO:tensorflow:loss = 0.036473162, step = 20300 (0.653 sec)
# INFO:tensorflow:global_step/sec: 153.929
# INFO:tensorflow:loss = 0.047626715, step = 20400 (0.651 sec)
# INFO:tensorflow:global_step/sec: 152.074
# INFO:tensorflow:loss = 0.09184779, step = 20500 (0.657 sec)
# INFO:tensorflow:global_step/sec: 149.712
# INFO:tensorflow:loss = 0.03681775, step = 20600 (0.667 sec)
# INFO:tensorflow:global_step/sec: 150.194
# INFO:tensorflow:loss = 0.034620363, step = 20700 (0.667 sec)
# INFO:tensorflow:global_step/sec: 148.55
# INFO:tensorflow:loss = 0.0280004, step = 20800 (0.672 sec)
# INFO:tensorflow:global_step/sec: 144.455
# INFO:tensorflow:loss = 0.06167559, step = 20900 (0.693 sec)
# INFO:tensorflow:global_step/sec: 152.675
# INFO:tensorflow:loss = 0.05338027, step = 21000 (0.655 sec)
# INFO:tensorflow:global_step/sec: 139.89
# INFO:tensorflow:loss = 0.047809508, step = 21100 (0.714 sec)
# INFO:tensorflow:global_step/sec: 149.745
# INFO:tensorflow:loss = 0.04948537, step = 21200 (0.668 sec)
# INFO:tensorflow:global_step/sec: 147.141
# INFO:tensorflow:loss = 0.053029552, step = 21300 (0.681 sec)
# INFO:tensorflow:global_step/sec: 135.912
# INFO:tensorflow:loss = 0.04151084, step = 21400 (0.736 sec)
# INFO:tensorflow:global_step/sec: 136.362
# INFO:tensorflow:loss = 0.02688723, step = 21500 (0.732 sec)
# INFO:tensorflow:global_step/sec: 153.026
# INFO:tensorflow:loss = 0.011789907, step = 21600 (0.657 sec)
# INFO:tensorflow:global_step/sec: 151.412
# INFO:tensorflow:loss = 0.056295425, step = 21700 (0.657 sec)
# INFO:tensorflow:global_step/sec: 148.559
# INFO:tensorflow:loss = 0.036511615, step = 21800 (0.673 sec)
# INFO:tensorflow:global_step/sec: 151.392
# INFO:tensorflow:loss = 0.041065834, step = 21900 (0.660 sec)
# INFO:tensorflow:global_step/sec: 149.842
# INFO:tensorflow:loss = 0.017303571, step = 22000 (0.668 sec)
# INFO:tensorflow:global_step/sec: 137.013
# INFO:tensorflow:loss = 0.06503831, step = 22100 (0.732 sec)
# INFO:tensorflow:global_step/sec: 147.82
# INFO:tensorflow:loss = 0.032755926, step = 22200 (0.680 sec)
# INFO:tensorflow:global_step/sec: 148.169
# INFO:tensorflow:loss = 0.013695532, step = 22300 (0.670 sec)
# INFO:tensorflow:global_step/sec: 142.626
# INFO:tensorflow:loss = 0.034058116, step = 22400 (0.702 sec)
# INFO:tensorflow:global_step/sec: 157.875
# INFO:tensorflow:loss = 0.021299854, step = 22500 (0.631 sec)
# INFO:tensorflow:global_step/sec: 150.613
# INFO:tensorflow:loss = 0.046947174, step = 22600 (0.666 sec)
# INFO:tensorflow:global_step/sec: 145.729
# INFO:tensorflow:loss = 0.01746143, step = 22700 (0.685 sec)
# INFO:tensorflow:global_step/sec: 152.502
# INFO:tensorflow:loss = 0.03688316, step = 22800 (0.659 sec)
# INFO:tensorflow:global_step/sec: 147.857
# INFO:tensorflow:loss = 0.03296389, step = 22900 (0.673 sec)
# INFO:tensorflow:global_step/sec: 147.819
# INFO:tensorflow:loss = 0.10756272, step = 23000 (0.679 sec)
# INFO:tensorflow:global_step/sec: 144.127
# INFO:tensorflow:loss = 0.030601794, step = 23100 (0.691 sec)
# INFO:tensorflow:global_step/sec: 154.374
# INFO:tensorflow:loss = 0.011340067, step = 23200 (0.648 sec)
# INFO:tensorflow:global_step/sec: 144.81
# INFO:tensorflow:loss = 0.036956444, step = 23300 (0.695 sec)
# INFO:tensorflow:global_step/sec: 147.422
# INFO:tensorflow:loss = 0.03421528, step = 23400 (0.674 sec)
# INFO:tensorflow:global_step/sec: 152.162
# INFO:tensorflow:loss = 0.03484336, step = 23500 (0.659 sec)
# INFO:tensorflow:global_step/sec: 152.109
# INFO:tensorflow:loss = 0.03123276, step = 23600 (0.656 sec)
# INFO:tensorflow:global_step/sec: 149.741
# INFO:tensorflow:loss = 0.06980765, step = 23700 (0.666 sec)
# INFO:tensorflow:global_step/sec: 151.312
# INFO:tensorflow:loss = 0.04281082, step = 23800 (0.663 sec)
# INFO:tensorflow:global_step/sec: 142.567
# INFO:tensorflow:loss = 0.023486866, step = 23900 (0.700 sec)
# INFO:tensorflow:global_step/sec: 152.706
# INFO:tensorflow:loss = 0.01831572, step = 24000 (0.655 sec)
# INFO:tensorflow:global_step/sec: 149.746
# INFO:tensorflow:loss = 0.035812184, step = 24100 (0.674 sec)
# INFO:tensorflow:global_step/sec: 151.692
# INFO:tensorflow:loss = 0.026479851, step = 24200 (0.654 sec)
# INFO:tensorflow:global_step/sec: 145.991
# INFO:tensorflow:loss = 0.032648683, step = 24300 (0.685 sec)
# INFO:tensorflow:global_step/sec: 153.787
# INFO:tensorflow:loss = 0.028951172, step = 24400 (0.649 sec)
# INFO:tensorflow:global_step/sec: 145.315
# INFO:tensorflow:loss = 0.054009788, step = 24500 (0.693 sec)
# INFO:tensorflow:global_step/sec: 147.199
# INFO:tensorflow:loss = 0.028091755, step = 24600 (0.674 sec)
# INFO:tensorflow:global_step/sec: 150.326
# INFO:tensorflow:loss = 0.042988054, step = 24700 (0.665 sec)
# INFO:tensorflow:global_step/sec: 139.44
# INFO:tensorflow:loss = 0.043358933, step = 24800 (0.718 sec)
# INFO:tensorflow:global_step/sec: 149.776
# INFO:tensorflow:loss = 0.034208648, step = 24900 (0.667 sec)
# INFO:tensorflow:global_step/sec: 151.293
# INFO:tensorflow:loss = 0.014915785, step = 25000 (0.661 sec)
# INFO:tensorflow:global_step/sec: 124.807
# INFO:tensorflow:loss = 0.027747514, step = 25100 (0.801 sec)
# INFO:tensorflow:global_step/sec: 139.843
# INFO:tensorflow:loss = 0.04698702, step = 25200 (0.715 sec)
# INFO:tensorflow:global_step/sec: 148.674
# INFO:tensorflow:loss = 0.032314632, step = 25300 (0.673 sec)
# INFO:tensorflow:global_step/sec: 142.435
# INFO:tensorflow:loss = 0.042002726, step = 25400 (0.706 sec)
# INFO:tensorflow:global_step/sec: 141.21
# INFO:tensorflow:loss = 0.024052208, step = 25500 (0.706 sec)
# INFO:tensorflow:global_step/sec: 136.555
# INFO:tensorflow:loss = 0.025377993, step = 25600 (0.731 sec)
# INFO:tensorflow:global_step/sec: 150.357
# INFO:tensorflow:loss = 0.048447013, step = 25700 (0.664 sec)
# INFO:tensorflow:global_step/sec: 155.379
# INFO:tensorflow:loss = 0.07928055, step = 25800 (0.648 sec)
# INFO:tensorflow:global_step/sec: 154.204
# INFO:tensorflow:loss = 0.023875274, step = 25900 (0.646 sec)
# INFO:tensorflow:global_step/sec: 154.007
# INFO:tensorflow:loss = 0.08412462, step = 26000 (0.652 sec)
# INFO:tensorflow:global_step/sec: 153.469
# INFO:tensorflow:loss = 0.04013239, step = 26100 (0.652 sec)
# INFO:tensorflow:global_step/sec: 150.663
# INFO:tensorflow:loss = 0.05920519, step = 26200 (0.660 sec)
# INFO:tensorflow:global_step/sec: 153.969
# INFO:tensorflow:loss = 0.035236567, step = 26300 (0.650 sec)
# INFO:tensorflow:global_step/sec: 154.831
# INFO:tensorflow:loss = 0.019911567, step = 26400 (0.647 sec)
# INFO:tensorflow:global_step/sec: 146.656
# INFO:tensorflow:loss = 0.039116032, step = 26500 (0.681 sec)
# INFO:tensorflow:global_step/sec: 152.174
# INFO:tensorflow:loss = 0.045251258, step = 26600 (0.661 sec)
# INFO:tensorflow:global_step/sec: 148.85
# INFO:tensorflow:loss = 0.01629226, step = 26700 (0.669 sec)
# INFO:tensorflow:global_step/sec: 155.604
# INFO:tensorflow:loss = 0.0533506, step = 26800 (0.643 sec)
# INFO:tensorflow:global_step/sec: 154.31
# INFO:tensorflow:loss = 0.027698783, step = 26900 (0.648 sec)
# INFO:tensorflow:global_step/sec: 147.624
# INFO:tensorflow:loss = 0.03970539, step = 27000 (0.678 sec)
# INFO:tensorflow:global_step/sec: 150.367
# INFO:tensorflow:loss = 0.0461539, step = 27100 (0.663 sec)
# INFO:tensorflow:global_step/sec: 157.509
# INFO:tensorflow:loss = 0.023598695, step = 27200 (0.635 sec)
# INFO:tensorflow:global_step/sec: 155.616
# INFO:tensorflow:loss = 0.035690226, step = 27300 (0.647 sec)
# INFO:tensorflow:global_step/sec: 147.996
# INFO:tensorflow:loss = 0.0367282, step = 27400 (0.672 sec)
# INFO:tensorflow:global_step/sec: 154.841
# INFO:tensorflow:loss = 0.035400838, step = 27500 (0.648 sec)
# INFO:tensorflow:global_step/sec: 139.833
# INFO:tensorflow:loss = 0.035778496, step = 27600 (0.715 sec)
# INFO:tensorflow:global_step/sec: 152.564
# INFO:tensorflow:loss = 0.05823549, step = 27700 (0.653 sec)
# INFO:tensorflow:global_step/sec: 155.324
# INFO:tensorflow:loss = 0.067181155, step = 27800 (0.645 sec)
# INFO:tensorflow:global_step/sec: 152.017
# INFO:tensorflow:loss = 0.011806035, step = 27900 (0.657 sec)
# INFO:tensorflow:global_step/sec: 154.655
# INFO:tensorflow:loss = 0.028718147, step = 28000 (0.648 sec)
# INFO:tensorflow:global_step/sec: 149.216
# INFO:tensorflow:loss = 0.040146623, step = 28100 (0.669 sec)
# INFO:tensorflow:global_step/sec: 148.687
# INFO:tensorflow:loss = 0.029818002, step = 28200 (0.676 sec)
# INFO:tensorflow:global_step/sec: 147.537
# INFO:tensorflow:loss = 0.057666652, step = 28300 (0.676 sec)
# INFO:tensorflow:global_step/sec: 139.07
# INFO:tensorflow:loss = 0.024861848, step = 28400 (0.722 sec)
# INFO:tensorflow:global_step/sec: 146.979
# INFO:tensorflow:loss = 0.045310408, step = 28500 (0.677 sec)
# INFO:tensorflow:global_step/sec: 146.958
# INFO:tensorflow:loss = 0.036566705, step = 28600 (0.680 sec)
# INFO:tensorflow:global_step/sec: 150.805
# INFO:tensorflow:loss = 0.019591067, step = 28700 (0.662 sec)
# INFO:tensorflow:global_step/sec: 147.843
# INFO:tensorflow:loss = 0.028065842, step = 28800 (0.679 sec)
# INFO:tensorflow:global_step/sec: 146.326
# INFO:tensorflow:loss = 0.029033585, step = 28900 (0.686 sec)
# INFO:tensorflow:global_step/sec: 151.427
# INFO:tensorflow:loss = 0.012629831, step = 29000 (0.655 sec)
# INFO:tensorflow:global_step/sec: 152.985
# INFO:tensorflow:loss = 0.0334359, step = 29100 (0.658 sec)
# INFO:tensorflow:global_step/sec: 146.955
# INFO:tensorflow:loss = 0.035499923, step = 29200 (0.675 sec)
# INFO:tensorflow:global_step/sec: 149.83
# INFO:tensorflow:loss = 0.027166361, step = 29300 (0.667 sec)
# INFO:tensorflow:global_step/sec: 146.761
# INFO:tensorflow:loss = 0.027602054, step = 29400 (0.681 sec)
# INFO:tensorflow:global_step/sec: 142.628
# INFO:tensorflow:loss = 0.07369794, step = 29500 (0.701 sec)
# INFO:tensorflow:global_step/sec: 153.966
# INFO:tensorflow:loss = 0.04369036, step = 29600 (0.650 sec)
# INFO:tensorflow:global_step/sec: 147.826
# INFO:tensorflow:loss = 0.05735763, step = 29700 (0.675 sec)
# INFO:tensorflow:global_step/sec: 153.501
# INFO:tensorflow:loss = 0.05949512, step = 29800 (0.651 sec)
# INFO:tensorflow:global_step/sec: 157.415
# INFO:tensorflow:loss = 0.05172516, step = 29900 (0.635 sec)
# INFO:tensorflow:global_step/sec: 145.953
# INFO:tensorflow:loss = 0.03524623, step = 30000 (0.686 sec)
# INFO:tensorflow:global_step/sec: 149.873
# INFO:tensorflow:loss = 0.03962095, step = 30100 (0.667 sec)
# INFO:tensorflow:global_step/sec: 153.503
# INFO:tensorflow:loss = 0.04644122, step = 30200 (0.652 sec)
# INFO:tensorflow:global_step/sec: 156.274
# INFO:tensorflow:loss = 0.016376272, step = 30300 (0.639 sec)
# INFO:tensorflow:global_step/sec: 157.202
# INFO:tensorflow:loss = 0.062400825, step = 30400 (0.635 sec)
# INFO:tensorflow:global_step/sec: 153.932
# INFO:tensorflow:loss = 0.04289145, step = 30500 (0.650 sec)
# INFO:tensorflow:global_step/sec: 155.926
# INFO:tensorflow:loss = 0.052667618, step = 30600 (0.644 sec)
# INFO:tensorflow:global_step/sec: 157.695
# INFO:tensorflow:loss = 0.049086884, step = 30700 (0.637 sec)
# INFO:tensorflow:global_step/sec: 147.805
# INFO:tensorflow:loss = 0.06551769, step = 30800 (0.671 sec)
# INFO:tensorflow:global_step/sec: 156.587
# INFO:tensorflow:loss = 0.014931659, step = 30900 (0.644 sec)
# INFO:tensorflow:global_step/sec: 148.783
# INFO:tensorflow:loss = 0.052787025, step = 31000 (0.667 sec)
# INFO:tensorflow:global_step/sec: 150.936
# INFO:tensorflow:loss = 0.055895235, step = 31100 (0.664 sec)
# INFO:tensorflow:global_step/sec: 148.421
# INFO:tensorflow:loss = 0.026622185, step = 31200 (0.672 sec)
# INFO:tensorflow:global_step/sec: 149.876
# INFO:tensorflow:loss = 0.035771206, step = 31300 (0.668 sec)
# INFO:tensorflow:global_step/sec: 139.983
# INFO:tensorflow:loss = 0.06667293, step = 31400 (0.714 sec)
# INFO:tensorflow:global_step/sec: 148.402
# INFO:tensorflow:loss = 0.030023009, step = 31500 (0.673 sec)
# INFO:tensorflow:global_step/sec: 151.93
# INFO:tensorflow:loss = 0.022352606, step = 31600 (0.659 sec)
# INFO:tensorflow:global_step/sec: 145.576
# INFO:tensorflow:loss = 0.045382816, step = 31700 (0.686 sec)
# INFO:tensorflow:global_step/sec: 152.505
# INFO:tensorflow:loss = 0.050091654, step = 31800 (0.662 sec)
# INFO:tensorflow:global_step/sec: 147.163
# INFO:tensorflow:loss = 0.038964435, step = 31900 (0.674 sec)
# INFO:tensorflow:global_step/sec: 149.929
# INFO:tensorflow:loss = 0.03492042, step = 32000 (0.667 sec)
# INFO:tensorflow:global_step/sec: 147.049
# INFO:tensorflow:loss = 0.04934053, step = 32100 (0.680 sec)
# INFO:tensorflow:global_step/sec: 153.196
# INFO:tensorflow:loss = 0.030408455, step = 32200 (0.653 sec)
# INFO:tensorflow:global_step/sec: 147.286
# INFO:tensorflow:loss = 0.01998917, step = 32300 (0.679 sec)
# INFO:tensorflow:global_step/sec: 156.01
# INFO:tensorflow:loss = 0.036248237, step = 32400 (0.646 sec)
# INFO:tensorflow:global_step/sec: 147.954
# INFO:tensorflow:loss = 0.06351559, step = 32500 (0.671 sec)
# INFO:tensorflow:global_step/sec: 144.944
# INFO:tensorflow:loss = 0.010003164, step = 32600 (0.696 sec)
# INFO:tensorflow:global_step/sec: 149.857
# INFO:tensorflow:loss = 0.07282819, step = 32700 (0.666 sec)
# INFO:tensorflow:global_step/sec: 146.79
# INFO:tensorflow:loss = 0.033092823, step = 32800 (0.678 sec)
# INFO:tensorflow:global_step/sec: 155.868
# INFO:tensorflow:loss = 0.03734357, step = 32900 (0.640 sec)
# INFO:tensorflow:global_step/sec: 148.565
# INFO:tensorflow:loss = 0.02024956, step = 33000 (0.673 sec)
# INFO:tensorflow:global_step/sec: 147.426
# INFO:tensorflow:loss = 0.01992619, step = 33100 (0.679 sec)
# INFO:tensorflow:global_step/sec: 149.577
# INFO:tensorflow:loss = 0.094431676, step = 33200 (0.668 sec)
# INFO:tensorflow:global_step/sec: 156.576
# INFO:tensorflow:loss = 0.031030606, step = 33300 (0.643 sec)
# INFO:tensorflow:global_step/sec: 148.133
# INFO:tensorflow:loss = 0.055233005, step = 33400 (0.670 sec)
# INFO:tensorflow:global_step/sec: 147.492
# INFO:tensorflow:loss = 0.03206329, step = 33500 (0.680 sec)
# INFO:tensorflow:global_step/sec: 151.187
# INFO:tensorflow:loss = 0.030494008, step = 33600 (0.659 sec)
# INFO:tensorflow:global_step/sec: 155.015
# INFO:tensorflow:loss = 0.022446867, step = 33700 (0.645 sec)
# INFO:tensorflow:global_step/sec: 150.824
# INFO:tensorflow:loss = 0.05677063, step = 33800 (0.664 sec)
# INFO:tensorflow:global_step/sec: 151.754
# INFO:tensorflow:loss = 0.013206489, step = 33900 (0.661 sec)
# INFO:tensorflow:global_step/sec: 153.759
# INFO:tensorflow:loss = 0.044998676, step = 34000 (0.652 sec)
# INFO:tensorflow:global_step/sec: 145.223
# INFO:tensorflow:loss = 0.03340192, step = 34100 (0.685 sec)
# INFO:tensorflow:global_step/sec: 149.62
# INFO:tensorflow:loss = 0.088927075, step = 34200 (0.667 sec)
# INFO:tensorflow:global_step/sec: 148.96
# INFO:tensorflow:loss = 0.021287382, step = 34300 (0.671 sec)
# INFO:tensorflow:global_step/sec: 148.106
# INFO:tensorflow:loss = 0.047253508, step = 34400 (0.676 sec)
# INFO:tensorflow:global_step/sec: 146.142
# INFO:tensorflow:loss = 0.03715685, step = 34500 (0.684 sec)
# INFO:tensorflow:global_step/sec: 155.343
# INFO:tensorflow:loss = 0.051838428, step = 34600 (0.646 sec)
# INFO:tensorflow:global_step/sec: 154.557
# INFO:tensorflow:loss = 0.054591954, step = 34700 (0.644 sec)
# INFO:tensorflow:global_step/sec: 153.629
# INFO:tensorflow:loss = 0.051670063, step = 34800 (0.655 sec)
# INFO:tensorflow:global_step/sec: 155.103
# INFO:tensorflow:loss = 0.05458607, step = 34900 (0.642 sec)
# INFO:tensorflow:global_step/sec: 147.181
# INFO:tensorflow:loss = 0.017366774, step = 35000 (0.678 sec)
# INFO:tensorflow:global_step/sec: 152.337
# INFO:tensorflow:loss = 0.032018133, step = 35100 (0.657 sec)
# INFO:tensorflow:global_step/sec: 151.767
# INFO:tensorflow:loss = 0.049008623, step = 35200 (0.660 sec)
# INFO:tensorflow:global_step/sec: 152.306
# INFO:tensorflow:loss = 0.03053783, step = 35300 (0.655 sec)
# INFO:tensorflow:global_step/sec: 152.831
# INFO:tensorflow:loss = 0.014865516, step = 35400 (0.659 sec)
# INFO:tensorflow:global_step/sec: 151.336
# INFO:tensorflow:loss = 0.056179907, step = 35500 (0.656 sec)
# INFO:tensorflow:global_step/sec: 152.394
# INFO:tensorflow:loss = 0.080065235, step = 35600 (0.661 sec)
# INFO:tensorflow:global_step/sec: 137.537
# INFO:tensorflow:loss = 0.02743633, step = 35700 (0.722 sec)
# INFO:tensorflow:global_step/sec: 139.736
# INFO:tensorflow:loss = 0.012036285, step = 35800 (0.716 sec)
# INFO:tensorflow:global_step/sec: 149.24
# INFO:tensorflow:loss = 0.036056742, step = 35900 (0.670 sec)
# INFO:tensorflow:global_step/sec: 146.736
# INFO:tensorflow:loss = 0.027278207, step = 36000 (0.683 sec)
# INFO:tensorflow:global_step/sec: 150.097
# INFO:tensorflow:loss = 0.035672434, step = 36100 (0.666 sec)
# INFO:tensorflow:global_step/sec: 150.319
# INFO:tensorflow:loss = 0.024036322, step = 36200 (0.664 sec)
# INFO:tensorflow:global_step/sec: 149.197
# INFO:tensorflow:loss = 0.064754926, step = 36300 (0.671 sec)
# INFO:tensorflow:global_step/sec: 143.409
# INFO:tensorflow:loss = 0.034335535, step = 36400 (0.696 sec)
# INFO:tensorflow:global_step/sec: 153.505
# INFO:tensorflow:loss = 0.03799866, step = 36500 (0.652 sec)
# INFO:tensorflow:global_step/sec: 150.648
# INFO:tensorflow:loss = 0.01972296, step = 36600 (0.664 sec)
# INFO:tensorflow:global_step/sec: 152.99
# INFO:tensorflow:loss = 0.027508928, step = 36700 (0.655 sec)
# INFO:tensorflow:global_step/sec: 152.844
# INFO:tensorflow:loss = 0.03129445, step = 36800 (0.655 sec)
# INFO:tensorflow:global_step/sec: 152.899
# INFO:tensorflow:loss = 0.054298658, step = 36900 (0.652 sec)
# INFO:tensorflow:global_step/sec: 150.78
# INFO:tensorflow:loss = 0.021916706, step = 37000 (0.663 sec)
# INFO:tensorflow:global_step/sec: 159.634
# INFO:tensorflow:loss = 0.063278064, step = 37100 (0.625 sec)
# INFO:tensorflow:global_step/sec: 146.001
# INFO:tensorflow:loss = 0.034541912, step = 37200 (0.688 sec)
# INFO:tensorflow:global_step/sec: 149.66
# INFO:tensorflow:loss = 0.021727787, step = 37300 (0.669 sec)
# INFO:tensorflow:global_step/sec: 149.425
# INFO:tensorflow:loss = 0.017690409, step = 37400 (0.666 sec)
# INFO:tensorflow:global_step/sec: 154.85
# INFO:tensorflow:loss = 0.023018327, step = 37500 (0.650 sec)
# INFO:tensorflow:global_step/sec: 146.981
# INFO:tensorflow:loss = 0.04010223, step = 37600 (0.675 sec)
# INFO:tensorflow:global_step/sec: 143.34
# INFO:tensorflow:loss = 0.041455492, step = 37700 (0.698 sec)
# INFO:tensorflow:global_step/sec: 157.156
# INFO:tensorflow:loss = 0.033151243, step = 37800 (0.637 sec)
# INFO:tensorflow:global_step/sec: 145.959
# INFO:tensorflow:loss = 0.058648527, step = 37900 (0.688 sec)
# INFO:tensorflow:global_step/sec: 148.359
# INFO:tensorflow:loss = 0.044827156, step = 38000 (0.671 sec)
# INFO:tensorflow:global_step/sec: 156.647
# INFO:tensorflow:loss = 0.014914075, step = 38100 (0.637 sec)
# INFO:tensorflow:global_step/sec: 152.25
# INFO:tensorflow:loss = 0.0356924, step = 38200 (0.662 sec)
# INFO:tensorflow:global_step/sec: 147.771
# INFO:tensorflow:loss = 0.013416327, step = 38300 (0.673 sec)
# INFO:tensorflow:global_step/sec: 150.432
# INFO:tensorflow:loss = 0.027695367, step = 38400 (0.664 sec)
# INFO:tensorflow:global_step/sec: 145.662
# INFO:tensorflow:loss = 0.06935963, step = 38500 (0.688 sec)
# INFO:tensorflow:global_step/sec: 150.651
# INFO:tensorflow:loss = 0.028871763, step = 38600 (0.662 sec)
# INFO:tensorflow:global_step/sec: 157.042
# INFO:tensorflow:loss = 0.022416977, step = 38700 (0.643 sec)
# INFO:tensorflow:global_step/sec: 147.598
# INFO:tensorflow:loss = 0.051134534, step = 38800 (0.672 sec)
# INFO:tensorflow:global_step/sec: 147.574
# INFO:tensorflow:loss = 0.025945187, step = 38900 (0.679 sec)
# INFO:tensorflow:global_step/sec: 147.744
# INFO:tensorflow:loss = 0.040117092, step = 39000 (0.680 sec)
# INFO:tensorflow:global_step/sec: 147.616
# INFO:tensorflow:loss = 0.038007215, step = 39100 (0.673 sec)
# INFO:tensorflow:global_step/sec: 154.018
# INFO:tensorflow:loss = 0.06855674, step = 39200 (0.650 sec)
# INFO:tensorflow:global_step/sec: 153.802
# INFO:tensorflow:loss = 0.053967696, step = 39300 (0.650 sec)
# INFO:tensorflow:global_step/sec: 147.77
# INFO:tensorflow:loss = 0.05776628, step = 39400 (0.677 sec)
# INFO:tensorflow:global_step/sec: 148.424
# INFO:tensorflow:loss = 0.06271952, step = 39500 (0.673 sec)
# INFO:tensorflow:global_step/sec: 153.233
# INFO:tensorflow:loss = 0.0320782, step = 39600 (0.653 sec)
# INFO:tensorflow:global_step/sec: 154.107
# INFO:tensorflow:loss = 0.06933161, step = 39700 (0.649 sec)
# INFO:tensorflow:global_step/sec: 147.45
# INFO:tensorflow:loss = 0.0383598, step = 39800 (0.678 sec)
# INFO:tensorflow:global_step/sec: 155.696
# INFO:tensorflow:loss = 0.047740486, step = 39900 (0.646 sec)
# INFO:tensorflow:global_step/sec: 150.255
# INFO:tensorflow:loss = 0.04332614, step = 40000 (0.665 sec)
# INFO:tensorflow:global_step/sec: 147.986
# INFO:tensorflow:loss = 0.052973382, step = 40100 (0.673 sec)
# INFO:tensorflow:global_step/sec: 150.632
# INFO:tensorflow:loss = 0.054634523, step = 40200 (0.665 sec)
# INFO:tensorflow:global_step/sec: 151.372
# INFO:tensorflow:loss = 0.04152526, step = 40300 (0.664 sec)
# INFO:tensorflow:global_step/sec: 152.507
# INFO:tensorflow:loss = 0.019709572, step = 40400 (0.653 sec)
# INFO:tensorflow:global_step/sec: 151.792
# INFO:tensorflow:loss = 0.046371344, step = 40500 (0.659 sec)
# INFO:tensorflow:global_step/sec: 134.884
# INFO:tensorflow:loss = 0.021115752, step = 40600 (0.742 sec)
# INFO:tensorflow:global_step/sec: 153.459
# INFO:tensorflow:loss = 0.052050367, step = 40700 (0.650 sec)
# INFO:tensorflow:global_step/sec: 146.171
# INFO:tensorflow:loss = 0.026816098, step = 40800 (0.685 sec)
# INFO:tensorflow:global_step/sec: 154.064
# INFO:tensorflow:loss = 0.016327359, step = 40900 (0.648 sec)
# INFO:tensorflow:global_step/sec: 152.747
# INFO:tensorflow:loss = 0.0524266, step = 41000 (0.655 sec)
# INFO:tensorflow:global_step/sec: 151.244
# INFO:tensorflow:loss = 0.045057945, step = 41100 (0.662 sec)
# INFO:tensorflow:global_step/sec: 148.382
# INFO:tensorflow:loss = 0.022944324, step = 41200 (0.676 sec)
# INFO:tensorflow:global_step/sec: 147.017
# INFO:tensorflow:loss = 0.0147453565, step = 41300 (0.678 sec)
# INFO:tensorflow:global_step/sec: 149.656
# INFO:tensorflow:loss = 0.02270113, step = 41400 (0.668 sec)
# INFO:tensorflow:global_step/sec: 147.132
# INFO:tensorflow:loss = 0.011794465, step = 41500 (0.679 sec)
# INFO:tensorflow:global_step/sec: 150.035
# INFO:tensorflow:loss = 0.022566324, step = 41600 (0.666 sec)
# INFO:tensorflow:global_step/sec: 149.024
# INFO:tensorflow:loss = 0.044374723, step = 41700 (0.676 sec)
# INFO:tensorflow:global_step/sec: 139.84
# INFO:tensorflow:loss = 0.05111961, step = 41800 (0.713 sec)
# INFO:tensorflow:global_step/sec: 150.078
# INFO:tensorflow:loss = 0.031928126, step = 41900 (0.664 sec)
# INFO:tensorflow:global_step/sec: 147.65
# INFO:tensorflow:loss = 0.04042277, step = 42000 (0.678 sec)
# INFO:tensorflow:global_step/sec: 143.448
# INFO:tensorflow:loss = 0.064940125, step = 42100 (0.697 sec)
# INFO:tensorflow:global_step/sec: 153.051
# INFO:tensorflow:loss = 0.025646176, step = 42200 (0.651 sec)
# INFO:tensorflow:global_step/sec: 148.061
# INFO:tensorflow:loss = 0.042578183, step = 42300 (0.679 sec)
# INFO:tensorflow:global_step/sec: 151.732
# INFO:tensorflow:loss = 0.059434578, step = 42400 (0.656 sec)
# INFO:tensorflow:global_step/sec: 149.878
# INFO:tensorflow:loss = 0.044139117, step = 42500 (0.667 sec)
# INFO:tensorflow:global_step/sec: 147.174
# INFO:tensorflow:loss = 0.0695768, step = 42600 (0.679 sec)
# INFO:tensorflow:global_step/sec: 150.256
# INFO:tensorflow:loss = 0.011336315, step = 42700 (0.666 sec)
# INFO:tensorflow:global_step/sec: 150.553
# INFO:tensorflow:loss = 0.033901997, step = 42800 (0.665 sec)
# INFO:tensorflow:global_step/sec: 156.246
# INFO:tensorflow:loss = 0.030767985, step = 42900 (0.640 sec)
# INFO:tensorflow:global_step/sec: 139.027
# INFO:tensorflow:loss = 0.038726933, step = 43000 (0.721 sec)
# INFO:tensorflow:global_step/sec: 148.411
# INFO:tensorflow:loss = 0.02675156, step = 43100 (0.672 sec)
# INFO:tensorflow:global_step/sec: 149.369
# INFO:tensorflow:loss = 0.013607978, step = 43200 (0.669 sec)
# INFO:tensorflow:global_step/sec: 146.379
# INFO:tensorflow:loss = 0.03186409, step = 43300 (0.683 sec)
# INFO:tensorflow:global_step/sec: 152.205
# INFO:tensorflow:loss = 0.07227989, step = 43400 (0.662 sec)
# INFO:tensorflow:global_step/sec: 125.369
# INFO:tensorflow:loss = 0.030416133, step = 43500 (0.793 sec)
# INFO:tensorflow:global_step/sec: 136.791
# INFO:tensorflow:loss = 0.03632631, step = 43600 (0.732 sec)
# INFO:tensorflow:global_step/sec: 149.653
# INFO:tensorflow:loss = 0.031720396, step = 43700 (0.667 sec)
# INFO:tensorflow:global_step/sec: 151.228
# INFO:tensorflow:loss = 0.05106222, step = 43800 (0.662 sec)
# INFO:tensorflow:global_step/sec: 147.354
# INFO:tensorflow:loss = 0.076104425, step = 43900 (0.680 sec)
# INFO:tensorflow:global_step/sec: 146.945
# INFO:tensorflow:loss = 0.054538045, step = 44000 (0.682 sec)
# INFO:tensorflow:global_step/sec: 149.838
# INFO:tensorflow:loss = 0.05064837, step = 44100 (0.665 sec)
# INFO:tensorflow:global_step/sec: 153.426
# INFO:tensorflow:loss = 0.055532422, step = 44200 (0.652 sec)
# INFO:tensorflow:global_step/sec: 150.884
# INFO:tensorflow:loss = 0.07815032, step = 44300 (0.667 sec)
# INFO:tensorflow:global_step/sec: 151.047
# INFO:tensorflow:loss = 0.042723604, step = 44400 (0.656 sec)
# INFO:tensorflow:global_step/sec: 145.69
# INFO:tensorflow:loss = 0.036443632, step = 44500 (0.690 sec)
# INFO:tensorflow:global_step/sec: 140.59
# INFO:tensorflow:loss = 0.01572071, step = 44600 (0.707 sec)
# INFO:tensorflow:global_step/sec: 145.758
# INFO:tensorflow:loss = 0.020144377, step = 44700 (0.688 sec)
# INFO:tensorflow:global_step/sec: 142.76
# INFO:tensorflow:loss = 0.022451239, step = 44800 (0.701 sec)
# INFO:tensorflow:global_step/sec: 147.467
# INFO:tensorflow:loss = 0.046005428, step = 44900 (0.676 sec)
# INFO:tensorflow:global_step/sec: 144.843
# INFO:tensorflow:loss = 0.041748665, step = 45000 (0.696 sec)
# INFO:tensorflow:global_step/sec: 152.331
# INFO:tensorflow:loss = 0.042070027, step = 45100 (0.650 sec)
# INFO:tensorflow:global_step/sec: 144.504
# INFO:tensorflow:loss = 0.08087177, step = 45200 (0.697 sec)
# INFO:tensorflow:global_step/sec: 151.153
# INFO:tensorflow:loss = 0.057736695, step = 45300 (0.656 sec)
# INFO:tensorflow:global_step/sec: 142.529
# INFO:tensorflow:loss = 0.028982304, step = 45400 (0.702 sec)
# INFO:tensorflow:global_step/sec: 138.49
# INFO:tensorflow:loss = 0.05949852, step = 45500 (0.726 sec)
# INFO:tensorflow:global_step/sec: 145.005
# INFO:tensorflow:loss = 0.030218713, step = 45600 (0.687 sec)
# INFO:tensorflow:global_step/sec: 150.567
# INFO:tensorflow:loss = 0.062881365, step = 45700 (0.663 sec)
# INFO:tensorflow:global_step/sec: 144.683
# INFO:tensorflow:loss = 0.02430567, step = 45800 (0.691 sec)
# INFO:tensorflow:global_step/sec: 147.863
# INFO:tensorflow:loss = 0.013217069, step = 45900 (0.677 sec)
# INFO:tensorflow:global_step/sec: 151.971
# INFO:tensorflow:loss = 0.050185896, step = 46000 (0.660 sec)
# INFO:tensorflow:global_step/sec: 150.573
# INFO:tensorflow:loss = 0.020289978, step = 46100 (0.662 sec)
# INFO:tensorflow:global_step/sec: 143.981
# INFO:tensorflow:loss = 0.056562413, step = 46200 (0.695 sec)
# INFO:tensorflow:global_step/sec: 146.938
# INFO:tensorflow:loss = 0.020021735, step = 46300 (0.681 sec)
# INFO:tensorflow:global_step/sec: 142.521
# INFO:tensorflow:loss = 0.06073075, step = 46400 (0.701 sec)
# INFO:tensorflow:global_step/sec: 153.163
# INFO:tensorflow:loss = 0.02939324, step = 46500 (0.652 sec)
# INFO:tensorflow:global_step/sec: 150.866
# INFO:tensorflow:loss = 0.043442495, step = 46600 (0.664 sec)
# INFO:tensorflow:global_step/sec: 146.582
# INFO:tensorflow:loss = 0.016594805, step = 46700 (0.682 sec)
# INFO:tensorflow:global_step/sec: 151.079
# INFO:tensorflow:loss = 0.04463713, step = 46800 (0.666 sec)
# INFO:tensorflow:global_step/sec: 151.341
# INFO:tensorflow:loss = 0.010547752, step = 46900 (0.657 sec)
# INFO:tensorflow:global_step/sec: 147.791
# INFO:tensorflow:loss = 0.03866756, step = 47000 (0.676 sec)
# INFO:tensorflow:global_step/sec: 146.492
# INFO:tensorflow:loss = 0.01978314, step = 47100 (0.685 sec)
# INFO:tensorflow:global_step/sec: 150.023
# INFO:tensorflow:loss = 0.029994896, step = 47200 (0.667 sec)
# INFO:tensorflow:global_step/sec: 152.08
# INFO:tensorflow:loss = 0.040313188, step = 47300 (0.657 sec)
# INFO:tensorflow:global_step/sec: 144.248
# INFO:tensorflow:loss = 0.041960552, step = 47400 (0.692 sec)
# INFO:tensorflow:global_step/sec: 151.71
# INFO:tensorflow:loss = 0.043875054, step = 47500 (0.662 sec)
# INFO:tensorflow:global_step/sec: 146.652
# INFO:tensorflow:loss = 0.02405379, step = 47600 (0.681 sec)
# INFO:tensorflow:global_step/sec: 143.535
# INFO:tensorflow:loss = 0.033500295, step = 47700 (0.696 sec)
# INFO:tensorflow:global_step/sec: 152
# INFO:tensorflow:loss = 0.027704319, step = 47800 (0.659 sec)
# INFO:tensorflow:global_step/sec: 138.67
# INFO:tensorflow:loss = 0.054243043, step = 47900 (0.719 sec)
# INFO:tensorflow:global_step/sec: 149.891
# INFO:tensorflow:loss = 0.021562064, step = 48000 (0.667 sec)
# INFO:tensorflow:global_step/sec: 153.858
# INFO:tensorflow:loss = 0.034902688, step = 48100 (0.651 sec)
# INFO:tensorflow:global_step/sec: 146.591
# INFO:tensorflow:loss = 0.038863588, step = 48200 (0.682 sec)
# INFO:tensorflow:global_step/sec: 149.022
# INFO:tensorflow:loss = 0.04278528, step = 48300 (0.671 sec)
# INFO:tensorflow:global_step/sec: 150.02
# INFO:tensorflow:loss = 0.057911005, step = 48400 (0.666 sec)
# INFO:tensorflow:global_step/sec: 150.911
# INFO:tensorflow:loss = 0.027506832, step = 48500 (0.662 sec)
# INFO:tensorflow:global_step/sec: 146.278
# INFO:tensorflow:loss = 0.023738917, step = 48600 (0.685 sec)
# INFO:tensorflow:global_step/sec: 154.798
# INFO:tensorflow:loss = 0.06625927, step = 48700 (0.646 sec)
# INFO:tensorflow:global_step/sec: 144.131
# INFO:tensorflow:loss = 0.04885892, step = 48800 (0.697 sec)
# INFO:tensorflow:global_step/sec: 141.845
# INFO:tensorflow:loss = 0.07844761, step = 48900 (0.702 sec)
# INFO:tensorflow:global_step/sec: 145.527
# INFO:tensorflow:loss = 0.05624637, step = 49000 (0.687 sec)
# INFO:tensorflow:global_step/sec: 149.835
# INFO:tensorflow:loss = 0.041966856, step = 49100 (0.667 sec)
# INFO:tensorflow:global_step/sec: 146.154
# INFO:tensorflow:loss = 0.083649464, step = 49200 (0.683 sec)
# INFO:tensorflow:global_step/sec: 152.116
# INFO:tensorflow:loss = 0.02661734, step = 49300 (0.660 sec)
# INFO:tensorflow:global_step/sec: 152.202
# INFO:tensorflow:loss = 0.027682997, step = 49400 (0.654 sec)
# INFO:tensorflow:global_step/sec: 150.208
# INFO:tensorflow:loss = 0.026796209, step = 49500 (0.667 sec)
# INFO:tensorflow:global_step/sec: 152.82
# INFO:tensorflow:loss = 0.039658763, step = 49600 (0.654 sec)
# INFO:tensorflow:global_step/sec: 153.855
# INFO:tensorflow:loss = 0.062369145, step = 49700 (0.650 sec)
# INFO:tensorflow:global_step/sec: 149.83
# INFO:tensorflow:loss = 0.04044497, step = 49800 (0.666 sec)
# INFO:tensorflow:global_step/sec: 153.19
# INFO:tensorflow:loss = 0.039564095, step = 49900 (0.658 sec)
# INFO:tensorflow:global_step/sec: 143.69
# INFO:tensorflow:loss = 0.034194633, step = 50000 (0.691 sec)
# INFO:tensorflow:global_step/sec: 145
# INFO:tensorflow:loss = 0.06568526, step = 50100 (0.694 sec)
# INFO:tensorflow:global_step/sec: 145.379
# INFO:tensorflow:loss = 0.045980684, step = 50200 (0.684 sec)
# INFO:tensorflow:global_step/sec: 152.365
# INFO:tensorflow:loss = 0.03853789, step = 50300 (0.659 sec)
# INFO:tensorflow:global_step/sec: 146.944
# INFO:tensorflow:loss = 0.05670613, step = 50400 (0.678 sec)
# INFO:tensorflow:global_step/sec: 146.867
# INFO:tensorflow:loss = 0.023454245, step = 50500 (0.681 sec)
# INFO:tensorflow:global_step/sec: 145.811
# INFO:tensorflow:loss = 0.05006583, step = 50600 (0.686 sec)
# INFO:tensorflow:global_step/sec: 149.851
# INFO:tensorflow:loss = 0.07404103, step = 50700 (0.668 sec)
# INFO:tensorflow:global_step/sec: 145.912
# INFO:tensorflow:loss = 0.06914994, step = 50800 (0.689 sec)
# ...
# INFO:tensorflow:global_step/sec: 148.534
# INFO:tensorflow:loss = 0.021889761, step = 89600 (0.676 sec)
# INFO:tensorflow:global_step/sec: 147.84
# INFO:tensorflow:loss = 0.048795857, step = 89700 (0.673 sec)
# INFO:tensorflow:global_step/sec: 145.142
# INFO:tensorflow:loss = 0.019707974, step = 89800 (0.689 sec)
# INFO:tensorflow:global_step/sec: 154.04
# INFO:tensorflow:loss = 0.06828664, step = 89900 (0.648 sec)
# INFO:tensorflow:Saving checkpoints for 89913 into C:\Users\tim19\AppData\Local\Temp\tmp9aer9ixv\model.ckpt.
# INFO:tensorflow:global_step/sec: 20.0041
# INFO:tensorflow:loss = 0.029997092, step = 90000 (5.001 sec)
# INFO:tensorflow:global_step/sec: 136.524
# INFO:tensorflow:loss = 0.065504074, step = 90100 (0.733 sec)
# INFO:tensorflow:global_step/sec: 142.461
# INFO:tensorflow:loss = 0.054467946, step = 90200 (0.705 sec)
# INFO:tensorflow:global_step/sec: 147.886
# INFO:tensorflow:loss = 0.06407677, step = 90300 (0.670 sec)
# INFO:tensorflow:global_step/sec: 152.409
# INFO:tensorflow:loss = 0.058732845, step = 90400 (0.663 sec)
# INFO:tensorflow:global_step/sec: 149.055
# INFO:tensorflow:loss = 0.02132734, step = 90500 (0.668 sec)
# INFO:tensorflow:global_step/sec: 151.379
# INFO:tensorflow:loss = 0.035011712, step = 90600 (0.657 sec)
# INFO:tensorflow:global_step/sec: 147.782
# INFO:tensorflow:loss = 0.022174146, step = 90700 (0.677 sec)
# INFO:tensorflow:global_step/sec: 150.883
# INFO:tensorflow:loss = 0.04692613, step = 90800 (0.665 sec)
# INFO:tensorflow:global_step/sec: 150.698
# INFO:tensorflow:loss = 0.01587406, step = 90900 (0.665 sec)
# INFO:tensorflow:global_step/sec: 149.332
# INFO:tensorflow:loss = 0.05119554, step = 91000 (0.669 sec)
# INFO:tensorflow:global_step/sec: 144.477
# INFO:tensorflow:loss = 0.05288049, step = 91100 (0.691 sec)
# INFO:tensorflow:global_step/sec: 146.623
# INFO:tensorflow:loss = 0.03632898, step = 91200 (0.681 sec)
# INFO:tensorflow:global_step/sec: 142.35
# INFO:tensorflow:loss = 0.023097547, step = 91300 (0.706 sec)
# INFO:tensorflow:global_step/sec: 150.114
# INFO:tensorflow:loss = 0.020848716, step = 91400 (0.664 sec)
# INFO:tensorflow:global_step/sec: 144.2
# INFO:tensorflow:loss = 0.036406882, step = 91500 (0.693 sec)
# INFO:tensorflow:global_step/sec: 134.407
# INFO:tensorflow:loss = 0.02999384, step = 91600 (0.746 sec)
# INFO:tensorflow:global_step/sec: 143.653
# INFO:tensorflow:loss = 0.067091614, step = 91700 (0.697 sec)
# INFO:tensorflow:global_step/sec: 146.661
# INFO:tensorflow:loss = 0.046339307, step = 91800 (0.678 sec)
# INFO:tensorflow:global_step/sec: 149.843
# INFO:tensorflow:loss = 0.021673433, step = 91900 (0.672 sec)
# INFO:tensorflow:global_step/sec: 139.814
# INFO:tensorflow:loss = 0.04873125, step = 92000 (0.712 sec)
# INFO:tensorflow:global_step/sec: 142.496
# INFO:tensorflow:loss = 0.017587136, step = 92100 (0.704 sec)
# INFO:tensorflow:global_step/sec: 143.971
# INFO:tensorflow:loss = 0.00793216, step = 92200 (0.691 sec)
# INFO:tensorflow:global_step/sec: 145.526
# INFO:tensorflow:loss = 0.03185444, step = 92300 (0.688 sec)
# INFO:tensorflow:global_step/sec: 147.179
# INFO:tensorflow:loss = 0.020970736, step = 92400 (0.678 sec)
# INFO:tensorflow:global_step/sec: 149.961
# INFO:tensorflow:loss = 0.025490642, step = 92500 (0.668 sec)
# INFO:tensorflow:global_step/sec: 148.657
# INFO:tensorflow:loss = 0.05888639, step = 92600 (0.675 sec)
# INFO:tensorflow:global_step/sec: 144.395
# INFO:tensorflow:loss = 0.023041654, step = 92700 (0.691 sec)
# INFO:tensorflow:global_step/sec: 145.244
# INFO:tensorflow:loss = 0.08309208, step = 92800 (0.692 sec)
# INFO:tensorflow:global_step/sec: 148.267
# INFO:tensorflow:loss = 0.033797048, step = 92900 (0.669 sec)
# INFO:tensorflow:global_step/sec: 144.429
# INFO:tensorflow:loss = 0.031571068, step = 93000 (0.696 sec)
# INFO:tensorflow:global_step/sec: 146.656
# INFO:tensorflow:loss = 0.02919101, step = 93100 (0.683 sec)
# INFO:tensorflow:global_step/sec: 145.738
# INFO:tensorflow:loss = 0.01174409, step = 93200 (0.683 sec)
# INFO:tensorflow:global_step/sec: 148.542
# INFO:tensorflow:loss = 0.048760988, step = 93300 (0.673 sec)
# INFO:tensorflow:global_step/sec: 148.204
# INFO:tensorflow:loss = 0.031542458, step = 93400 (0.678 sec)
# INFO:tensorflow:global_step/sec: 147.89
# INFO:tensorflow:loss = 0.037665226, step = 93500 (0.672 sec)
# INFO:tensorflow:global_step/sec: 150.209
# INFO:tensorflow:loss = 0.080452055, step = 93600 (0.665 sec)
# INFO:tensorflow:global_step/sec: 150.403
# INFO:tensorflow:loss = 0.045215573, step = 93700 (0.665 sec)
# INFO:tensorflow:global_step/sec: 149.41
# INFO:tensorflow:loss = 0.0452205, step = 93800 (0.669 sec)
# INFO:tensorflow:global_step/sec: 149.208
# INFO:tensorflow:loss = 0.023377698, step = 93900 (0.672 sec)
# INFO:tensorflow:global_step/sec: 139.445
# INFO:tensorflow:loss = 0.019368801, step = 94000 (0.719 sec)
# INFO:tensorflow:global_step/sec: 149.797
# INFO:tensorflow:loss = 0.025934026, step = 94100 (0.669 sec)
# INFO:tensorflow:global_step/sec: 146.475
# INFO:tensorflow:loss = 0.01899441, step = 94200 (0.683 sec)
# INFO:tensorflow:global_step/sec: 146.785
# INFO:tensorflow:loss = 0.035882674, step = 94300 (0.681 sec)
# INFO:tensorflow:global_step/sec: 145.178
# INFO:tensorflow:loss = 0.07510556, step = 94400 (0.686 sec)
# INFO:tensorflow:global_step/sec: 148.596
# INFO:tensorflow:loss = 0.032578405, step = 94500 (0.671 sec)
# INFO:tensorflow:global_step/sec: 146.236
# INFO:tensorflow:loss = 0.051079687, step = 94600 (0.685 sec)
# INFO:tensorflow:global_step/sec: 146.42
# INFO:tensorflow:loss = 0.027882062, step = 94700 (0.682 sec)
# INFO:tensorflow:global_step/sec: 147.074
# INFO:tensorflow:loss = 0.057315223, step = 94800 (0.681 sec)
# INFO:tensorflow:global_step/sec: 145.882
# INFO:tensorflow:loss = 0.061951455, step = 94900 (0.685 sec)
# INFO:tensorflow:global_step/sec: 152.382
# INFO:tensorflow:loss = 0.039312657, step = 95000 (0.661 sec)
# INFO:tensorflow:global_step/sec: 146.594
# INFO:tensorflow:loss = 0.046835214, step = 95100 (0.681 sec)
# INFO:tensorflow:global_step/sec: 148.212
# INFO:tensorflow:loss = 0.047824025, step = 95200 (0.672 sec)
# INFO:tensorflow:global_step/sec: 152.653
# INFO:tensorflow:loss = 0.017422646, step = 95300 (0.655 sec)
# INFO:tensorflow:global_step/sec: 145.807
# INFO:tensorflow:loss = 0.07390931, step = 95400 (0.686 sec)
# INFO:tensorflow:global_step/sec: 140.619
# INFO:tensorflow:loss = 0.04119521, step = 95500 (0.710 sec)
# INFO:tensorflow:global_step/sec: 146.891
# INFO:tensorflow:loss = 0.041547097, step = 95600 (0.682 sec)
# INFO:tensorflow:global_step/sec: 148.4
# INFO:tensorflow:loss = 0.03591252, step = 95700 (0.676 sec)
# INFO:tensorflow:global_step/sec: 144.477
# INFO:tensorflow:loss = 0.081660785, step = 95800 (0.690 sec)
# INFO:tensorflow:global_step/sec: 150.126
# INFO:tensorflow:loss = 0.053254917, step = 95900 (0.664 sec)
# INFO:tensorflow:global_step/sec: 142.519
# INFO:tensorflow:loss = 0.024439149, step = 96000 (0.706 sec)
# INFO:tensorflow:global_step/sec: 138.775
# INFO:tensorflow:loss = 0.022079581, step = 96100 (0.719 sec)
# INFO:tensorflow:global_step/sec: 142.01
# INFO:tensorflow:loss = 0.029990528, step = 96200 (0.707 sec)
# INFO:tensorflow:global_step/sec: 148.325
# INFO:tensorflow:loss = 0.029826988, step = 96300 (0.671 sec)
# INFO:tensorflow:global_step/sec: 155.757
# INFO:tensorflow:loss = 0.030427665, step = 96400 (0.645 sec)
# INFO:tensorflow:global_step/sec: 149.127
# INFO:tensorflow:loss = 0.024845926, step = 96500 (0.669 sec)
# INFO:tensorflow:global_step/sec: 132.891
# INFO:tensorflow:loss = 0.026183868, step = 96600 (0.752 sec)
# INFO:tensorflow:global_step/sec: 152.219
# INFO:tensorflow:loss = 0.039208487, step = 96700 (0.656 sec)
# INFO:tensorflow:global_step/sec: 147.62
# INFO:tensorflow:loss = 0.023825154, step = 96800 (0.678 sec)
# INFO:tensorflow:global_step/sec: 154.43
# INFO:tensorflow:loss = 0.023307664, step = 96900 (0.647 sec)
# INFO:tensorflow:global_step/sec: 145.437
# INFO:tensorflow:loss = 0.05951217, step = 97000 (0.688 sec)
# INFO:tensorflow:global_step/sec: 148.579
# INFO:tensorflow:loss = 0.07131675, step = 97100 (0.677 sec)
# INFO:tensorflow:global_step/sec: 147.938
# INFO:tensorflow:loss = 0.037610438, step = 97200 (0.672 sec)
# INFO:tensorflow:global_step/sec: 150.616
# INFO:tensorflow:loss = 0.034869686, step = 97300 (0.664 sec)
# INFO:tensorflow:global_step/sec: 139.071
# INFO:tensorflow:loss = 0.010049977, step = 97400 (0.720 sec)
# INFO:tensorflow:global_step/sec: 147.154
# INFO:tensorflow:loss = 0.040443677, step = 97500 (0.679 sec)
# INFO:tensorflow:global_step/sec: 131.975
# INFO:tensorflow:loss = 0.05123495, step = 97600 (0.763 sec)
# INFO:tensorflow:global_step/sec: 136.112
# INFO:tensorflow:loss = 0.033992667, step = 97700 (0.736 sec)
# INFO:tensorflow:global_step/sec: 145.013
# INFO:tensorflow:loss = 0.06490172, step = 97800 (0.685 sec)
# INFO:tensorflow:global_step/sec: 140.683
# INFO:tensorflow:loss = 0.03965596, step = 97900 (0.715 sec)
# INFO:tensorflow:global_step/sec: 140.707
# INFO:tensorflow:loss = 0.028495412, step = 98000 (0.706 sec)
# INFO:tensorflow:global_step/sec: 145.811
# INFO:tensorflow:loss = 0.026281536, step = 98100 (0.689 sec)
# INFO:tensorflow:global_step/sec: 149.484
# INFO:tensorflow:loss = 0.014566259, step = 98200 (0.671 sec)
# INFO:tensorflow:global_step/sec: 150.772
# INFO:tensorflow:loss = 0.03119039, step = 98300 (0.660 sec)
# INFO:tensorflow:global_step/sec: 146.094
# INFO:tensorflow:loss = 0.045498326, step = 98400 (0.686 sec)
# INFO:tensorflow:global_step/sec: 146.88
# INFO:tensorflow:loss = 0.024972152, step = 98500 (0.678 sec)
# INFO:tensorflow:global_step/sec: 139.951
# INFO:tensorflow:loss = 0.04441569, step = 98600 (0.714 sec)
# INFO:tensorflow:global_step/sec: 145.771
# INFO:tensorflow:loss = 0.048270818, step = 98700 (0.689 sec)
# INFO:tensorflow:global_step/sec: 151.459
# INFO:tensorflow:loss = 0.03420996, step = 98800 (0.656 sec)
# INFO:tensorflow:global_step/sec: 141.483
# INFO:tensorflow:loss = 0.026549792, step = 98900 (0.708 sec)
# INFO:tensorflow:global_step/sec: 146.996
# INFO:tensorflow:loss = 0.017258406, step = 99000 (0.679 sec)
# INFO:tensorflow:global_step/sec: 139.612
# INFO:tensorflow:loss = 0.024765866, step = 99100 (0.718 sec)
# INFO:tensorflow:global_step/sec: 145.966
# INFO:tensorflow:loss = 0.019596238, step = 99200 (0.683 sec)
# INFO:tensorflow:global_step/sec: 146.807
# INFO:tensorflow:loss = 0.09106882, step = 99300 (0.682 sec)
# INFO:tensorflow:global_step/sec: 146.376
# INFO:tensorflow:loss = 0.04163035, step = 99400 (0.682 sec)
# INFO:tensorflow:global_step/sec: 149.587
# INFO:tensorflow:loss = 0.027412161, step = 99500 (0.671 sec)
# INFO:tensorflow:global_step/sec: 149.936
# INFO:tensorflow:loss = 0.022245634, step = 99600 (0.666 sec)
# INFO:tensorflow:global_step/sec: 141.604
# INFO:tensorflow:loss = 0.0716123, step = 99700 (0.705 sec)
# INFO:tensorflow:global_step/sec: 148.838
# INFO:tensorflow:loss = 0.03051934, step = 99800 (0.672 sec)
# INFO:tensorflow:global_step/sec: 139.593
# INFO:tensorflow:loss = 0.04180684, step = 99900 (0.715 sec)
# INFO:tensorflow:global_step/sec: 146.196
# INFO:tensorflow:loss = 0.056283347, step = 100000 (0.684 sec)
# INFO:tensorflow:global_step/sec: 146.473
# INFO:tensorflow:loss = 0.018621227, step = 100100 (0.683 sec)
# INFO:tensorflow:global_step/sec: 144.138
# INFO:tensorflow:loss = 0.062119346, step = 100200 (0.695 sec)
# INFO:tensorflow:global_step/sec: 149.7
# INFO:tensorflow:loss = 0.051719975, step = 100300 (0.668 sec)
# INFO:tensorflow:global_step/sec: 144.493
# INFO:tensorflow:loss = 0.0347395, step = 100400 (0.692 sec)
# INFO:tensorflow:global_step/sec: 141.853
# INFO:tensorflow:loss = 0.024494922, step = 100500 (0.706 sec)
# INFO:tensorflow:global_step/sec: 147.774
# INFO:tensorflow:loss = 0.05475001, step = 100600 (0.677 sec)
# INFO:tensorflow:global_step/sec: 146.138
# INFO:tensorflow:loss = 0.092142284, step = 100700 (0.685 sec)
# INFO:tensorflow:global_step/sec: 140.598
# INFO:tensorflow:loss = 0.07814273, step = 100800 (0.709 sec)
# INFO:tensorflow:global_step/sec: 130.509
# INFO:tensorflow:loss = 0.033259727, step = 100900 (0.766 sec)
# INFO:tensorflow:global_step/sec: 134.749
# INFO:tensorflow:loss = 0.025747202, step = 101000 (0.744 sec)
# INFO:tensorflow:global_step/sec: 135.525
# INFO:tensorflow:loss = 0.020423979, step = 101100 (0.736 sec)
# INFO:tensorflow:global_step/sec: 135.849
# INFO:tensorflow:loss = 0.021202056, step = 101200 (0.735 sec)
# INFO:tensorflow:global_step/sec: 150.388
# INFO:tensorflow:loss = 0.040560413, step = 101300 (0.666 sec)
# INFO:tensorflow:global_step/sec: 138.274
# INFO:tensorflow:loss = 0.039484262, step = 101400 (0.723 sec)
# INFO:tensorflow:global_step/sec: 140.825
# INFO:tensorflow:loss = 0.014818991, step = 101500 (0.709 sec)
# INFO:tensorflow:global_step/sec: 133.632
# INFO:tensorflow:loss = 0.027253605, step = 101600 (0.748 sec)
# INFO:tensorflow:global_step/sec: 137.684
# INFO:tensorflow:loss = 0.07163054, step = 101700 (0.731 sec)
# INFO:tensorflow:global_step/sec: 131.165
# INFO:tensorflow:loss = 0.07236706, step = 101800 (0.758 sec)
# INFO:tensorflow:global_step/sec: 132.355
# INFO:tensorflow:loss = 0.039459668, step = 101900 (0.757 sec)
# INFO:tensorflow:global_step/sec: 134.473
# INFO:tensorflow:loss = 0.028898306, step = 102000 (0.742 sec)
# INFO:tensorflow:global_step/sec: 133.834
# INFO:tensorflow:loss = 0.06694363, step = 102100 (0.748 sec)
# INFO:tensorflow:global_step/sec: 133.948
# INFO:tensorflow:loss = 0.07226381, step = 102200 (0.747 sec)
# INFO:tensorflow:global_step/sec: 157.386
# INFO:tensorflow:loss = 0.055035587, step = 102300 (0.635 sec)
# INFO:tensorflow:global_step/sec: 129.712
# INFO:tensorflow:loss = 0.03516375, step = 102400 (0.771 sec)
# INFO:tensorflow:global_step/sec: 133.626
# INFO:tensorflow:loss = 0.025974339, step = 102500 (0.748 sec)
# INFO:tensorflow:global_step/sec: 134.47
# INFO:tensorflow:loss = 0.02264998, step = 102600 (0.744 sec)
# INFO:tensorflow:global_step/sec: 129.589
# INFO:tensorflow:loss = 0.02869679, step = 102700 (0.772 sec)
# INFO:tensorflow:global_step/sec: 138.89
# INFO:tensorflow:loss = 0.039837264, step = 102800 (0.723 sec)
# INFO:tensorflow:global_step/sec: 152.186
# INFO:tensorflow:loss = 0.048875175, step = 102900 (0.653 sec)
# INFO:tensorflow:global_step/sec: 153.906
# INFO:tensorflow:loss = 0.04056576, step = 103000 (0.652 sec)
# INFO:tensorflow:global_step/sec: 131.743
# INFO:tensorflow:loss = 0.020619364, step = 103100 (0.761 sec)
# INFO:tensorflow:global_step/sec: 131.63
# INFO:tensorflow:loss = 0.028205447, step = 103200 (0.758 sec)
# INFO:tensorflow:global_step/sec: 148.595
# INFO:tensorflow:loss = 0.049536295, step = 103300 (0.675 sec)
# INFO:tensorflow:global_step/sec: 136.963
# INFO:tensorflow:loss = 0.033155616, step = 103400 (0.727 sec)
# INFO:tensorflow:global_step/sec: 157.014
# INFO:tensorflow:loss = 0.021916762, step = 103500 (0.640 sec)
# INFO:tensorflow:global_step/sec: 147.496
# INFO:tensorflow:loss = 0.03557526, step = 103600 (0.675 sec)
# INFO:tensorflow:global_step/sec: 154.247
# INFO:tensorflow:loss = 0.021680735, step = 103700 (0.647 sec)
# INFO:tensorflow:global_step/sec: 161.836
# INFO:tensorflow:loss = 0.047330108, step = 103800 (0.619 sec)
# INFO:tensorflow:global_step/sec: 141.219
# INFO:tensorflow:loss = 0.020779181, step = 103900 (0.709 sec)
# INFO:tensorflow:global_step/sec: 130.376
# INFO:tensorflow:loss = 0.023910005, step = 104000 (0.767 sec)
# INFO:tensorflow:global_step/sec: 144.938
# INFO:tensorflow:loss = 0.03606209, step = 104100 (0.688 sec)
# INFO:tensorflow:global_step/sec: 161.574
# INFO:tensorflow:loss = 0.010476118, step = 104200 (0.619 sec)
# INFO:tensorflow:global_step/sec: 158.744
# INFO:tensorflow:loss = 0.04082599, step = 104300 (0.630 sec)
# INFO:tensorflow:global_step/sec: 154.07
# INFO:tensorflow:loss = 0.055790167, step = 104400 (0.650 sec)
# INFO:tensorflow:global_step/sec: 158.556
# INFO:tensorflow:loss = 0.04216355, step = 104500 (0.630 sec)
# INFO:tensorflow:global_step/sec: 159.304
# INFO:tensorflow:loss = 0.053606153, step = 104600 (0.630 sec)
# INFO:tensorflow:global_step/sec: 155.836
# INFO:tensorflow:loss = 0.011811517, step = 104700 (0.640 sec)
# INFO:tensorflow:global_step/sec: 156.665
# INFO:tensorflow:loss = 0.034832828, step = 104800 (0.640 sec)
# INFO:tensorflow:global_step/sec: 155.185
# INFO:tensorflow:loss = 0.041103393, step = 104900 (0.643 sec)
# INFO:tensorflow:Saving checkpoints for 105000 into C:\Users\tim19\AppData\Local\Temp\tmp9aer9ixv\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.029596219.

# %% [markdown]
# ### Evaluate

# %%
results = model.evaluate(input_fn = lambda: eval_input_func(x_test, y_test, training=False))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-15T01:02:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\tim19\AppData\Local\Temp\tmp9aer9ixv\model.ckpt-105000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-15-01:02:34
# INFO:tensorflow:Saving dict for global step 105000: accuracy = 0.9867634, accuracy_baseline = 0.9865444, auc = 0.9420263, auc_precision_recall = 0.31993854, average_loss = 0.04014173, global_step = 105000, label/mean = 0.013455645, loss = 0.040165257, precision = 0.65337425, prediction/mean = 0.013078295, recall = 0.034673613
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 105000: C:\Users\tim19\AppData\Local\Temp\tmp9aer9ixv\model.ckpt-105000

# %%
results
# Out:
# {'accuracy': 0.9867634,
#  'accuracy_baseline': 0.9865444,
#  'auc': 0.9420263,
#  'auc_precision_recall': 0.31993854,
#  'average_loss': 0.04014173,
#  'label/mean': 0.013455645,
#  'loss': 0.040165257,
#  'precision': 0.65337425,
#  'prediction/mean': 0.013078295,
#  'recall': 0.034673613,
#  'global_step': 105000}

# %%
predictions = model.predict(input_fn = lambda: input_fn(tst_ready, training=False))

# %%
expected = ['fraud_ind']
# CATEGORY = ['Setosa', 'Versicolor', 'Virginica']
for pred_dict, expec in zip(predictions, expected):
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{}" ({:.1f}%), expected "{}"'.format(
        class_id, 100 * probability, expec))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\tim19\AppData\Local\Temp\tmp54zprb5r\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "0" (99.8%), expected "fraud_ind"

# %% [markdown]
# ### Plot
